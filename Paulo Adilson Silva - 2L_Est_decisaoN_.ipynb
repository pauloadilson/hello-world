# %% [markdown]
# ### 1. A nota final de um estudante é calculada a partir de três notas atribuídas, respectivamente, a um trabalho de laboratório, a uma avaliação semestral e a um exame final. A média das três notas mencionadas obedece aos pesos a seguir:**
#
#  NOTA |  PESO |
#  ---|---
# Trabalho de laboratório  |   2   |
# Avaliação semestral      |   3   |
# Exame final              |   5   |
#
# ### Faça um programa que receba as três notas, calcule e mostre a média ponderada e o conceito que segue a tabela
#
# MÉDIA PONDERADA    | CONCEITO|
# ---|---
# 8,0 <= média <= 10  |    A
# 7,0 <= média < 8,0  |    B
# 6,0 <= média < 7,0  |    C
# 5,0 <= média < 6,0  |    D
#  0,0 <= média < 5,0  |    E
#
# ```
# ESCREVA “Digite a nota do trabalho de laboratório: “
# LEIA nota_traballho
#
# ESCREVA “Digite a nota da avaliação semestral: “
# LEIA avalaliacao_semestral
#
# ESCREVA “Digite a nota do exame final: “
# LEIA exama_final
#
# media = (nota_traballho * 2 + avalaliacao_semestral * 3 + exame * 5) / 10
# ESCREVA “Média ponderada: “ , media
#
# SE media >= 8 E media <= 10
#     ESCREVA “Obteve conceito A”
# SE media >= 7 E media < 8
#     ESCREVA “Obteve conceito  B”
# SE media >= 6 E media < 7
#     ESCREVA “Obteve  conceito C”
# SE media >= 5 E media < 6
#     ESCREVA “Obteve conceito D”
# SE media >= 0 E media < 5
#     ESCREVA “Obteve conceito E”
# ```

# %%
# 1. Faça um programa que receba as três notas, calcule e mostre a média ponderada e o conceito que segue a tabela
trabLab = float(input("Qual a nota no trabalho de laboratório? "))
avSem = float(input("Qual a nota na avaliação semestral? "))
exFin = float(input("Qual a nota no exame final? "))
medPond = ((trabLab * 2)+(avSem * 3)+(exFin * 5))/10
print("A média ponderada na disciplina é {0:.1f}." .format(medPond))
if medPond < 5:
  print('Seu conceito é E.')
elif medPond < 6:
  print("Seu conceito é D.")
elif medPond < 7:
  print("Seu conceito é C.")
elif medPond < 8:
  print("Seu conceito é B.")
else:
  print("Seu conceito é A.")
# Out:
# Qual a nota no trabalho de laboratório? 9
# Qual a nota na avaliação semestral? 10
# Qual a nota no exame final? 10
# A média ponderada na disciplina é 9.8.
# Seu conceito é A.

# %% [markdown]
# ### 2. Faça um programa que receba três notas de um aluno, calcule e mostre a média aritmética e a mensagem constante na tabela a seguir. Aos alunos que ficaram para exame, calcule e mostre a nota que deverão tirar para serem aprovados, considerando que a média exigida é 6,0.
#
# MÉDIA ARITMÉTICA | MENSAGEM
#     ---|---
#     0,0 <= média < 3,0 |Reprovado
#     3,0 <= média < 7,0|Exame
#     7,0 <= média <= 10,0|Aprovado
#
# ```
# ESCREVA “Digite a primeira nota: “
# LEIA nota1
#
# ESCREVA “Digite a segunda nota: “
# LEIA nota2
#
# ESCREVA “Digite a terceira nota: “
# LEIA nota3
#
# media = (nota1 + nota2 + nota3) / 3
# ESCREVA “Média aritmética: “,media
#
# SE media >= 0 E media < 3
#     ESCREVA “Reprovado”
# SE media >= 3 E media < 7
#     ESCREVA “Exame”
# nota_exame = 12 - media
#     ESCREVA “Deve tirar nota”, nota_exame, “para ser aprovado”
# SE media >= 7 E media <= 10
#     ESCREVA “Aprovado”
# ```

# %%
#  2. Faça um programa que receba três notas de um aluno, calcule e mostre a média aritmética e a mensagem constante na tabela a seguir. 
p1 = float(input('Qual a nota na P1? '))
p2 = float(input('Qual a nota na P2? '))
p3 = float(input('Qual a nota na P3? '))
media = (p1 + p2 + p3) / 3
print("\nA média aritmética das notas do aluno é {0:.1f}." .format(media))
if media < 3:
   print('O aluno foi Reprovado.')
elif media <7:
   notaExame = 12 - media
   print('O aluno está em Exame e precisa tirar {0:.1f} para ser aprovado.' .format(notaExame))
else:
   print('O aluno está Aprovado.')
# Out:
# Qual a nota na P1? 6
# Qual a nota na P2? 8
# Qual a nota na P3? 5
#
# A média aritmética das notas do aluno é 6.3.
# O aluno está em Exame e precisa tirar 5.7 para ser aprovado.

# %% [markdown]
# ### 3. Faça um programa que receba dois números e mostre o maior.
#
# ```
# ESCREVA “Digite o primeiro número: “
# LEIA numero1
#
# ESCREVA “Digite o segundo número: “
# LEIA numero2
#
# SE numero1 > numero2
#     ESCREVA “O maior número é: “, numero1
# SE numero2 > numero1
#     ESCREVA “O maior número é: “, num2
# SE numero1 == numero1
#     ESCREVA “Os números são iguais “
# ```

# %%
# 3. Faça um programa que receba dois números e mostre o maior.
nro1 = float(input('Digite um número real qualquer: '))
nro2 = float(input('Digite outro número real qualquer: '))
if nro1 > nro2:
  print("O número {0} é o maior deles." .format(nro1))
elif nro1 == nro2:
  print("Os dois números digitados são iguais.")
else:
  print("O número {0} é o maior deles." .format(nro2))
# Out:
# Digite um número real qualquer: 56
# Digite outro número real qualquer: 65
# O número 65.0 é o maior deles.

# %% [markdown]
# ### 4. Faça um programa que receba três números e mostre-os em ordem crescente. Suponha que o usuário digitará três números diferentes.
#
# ```
# ESCREVA “Digite o primeiro número: “
# LEIA numero1
#
# ESCREVA “Digite o segundo número: “
# LEIA numero2
#
# ESCREVA “Digite o terceiro número: “
# LEIA numero3
#
# SE numero1 < numero2 E numero1 < numero3
#     SE numero2 < numero3
#         ESCREVA “A ordem crescente é: “,numero1,“-”,numero2,“-”,numero3
#     SENÃO
#         ESCREVA “A ordem crescente é: “,numero1,“-”,num3,“-”,num2
# SE numero2 < numero1 E numero2 < numero3
#     SE numero1 < numero3
#         ESCREVA “A ordem crescente é: “,numero2,“-”,numero1,“-”,numero3
#     SENÃO
#         ESCREVA “A ordem crescente é: “,numero2,“-”,numero3,“-”,numero
# SE numero3 < numero1 E numero3 < num2
#     SE numero1 < numero2
#     ESCREVA “A ordem crescente é: “,numero3,“-”,numero1,“-”,numero2
#   ```

# %%
# 4. Digite seu código aqui
nro1 = float(input('Digite um número real qualquer: '))
nro2 = float(input('Digite outro número real qualquer diferente: '))
nro3 = float(input('Digite outro número real qualquer diferente dos dois anteriores: '))
if nro1 > nro2 and nro1 > nro3:
  if nro2 > nro3:
    print("Os números em ordem crescente são {0}, {1} e {2}." .format(nro3,nro2,nro1))
  else:
    print("Os números em ordem crescente são {0}, {1} e {2}." .format(nro2,nro3,nro1))
elif nro2 > nro1 and nro2 > nro3:
  if nro1 > nro3:
    print("Os números em ordem crescente são {0}, {1} e {2}." .format(nro3,nro2,nro2))
  else:
    print("Os números em ordem crescente são {0}, {1} e {2}." .format(nro1,nro3,nro2))
else:
  if nro1 > nro2:
    print("Os números em ordem crescente são {0}, {1} e {2}." .format(nro2,nro1,nro3))
  else:
    print("Os números em ordem crescente são {0}, {1} e {2}." .format(nro1,nro2,nro3))
# Out:
# Digite um número real qualquer: 654
# Digite outro número real qualquer diferente: 65
# Digite outro número real qualquer diferente dos dois anteriores: 56
# Os números em ordem crescente são 56.0, 65.0 e 654.0.

# %% [markdown]
# ### 5. Faça um programa que receba três números obrigatoriamente em ordem crescente e um quarto número que não siga essa regra. Mostre, em seguida, os quatro números em ordem decrescente. Suponha que o usuário digitará quatro números diferentes.
#
# ```code
# ESCREVA “Digite três números em ordem crescente: “
# LEIA numero1
# LEIA numero2
# LEIA numero3
#
# ESCREVA “Digite um número (fora de ordem): “
# LEIA numero4
#
# SE numero4 > numero3
#     ESCREVA “A ordem decrescente é: “,numero4,“-”,numero3,“-”,numero2,“-”,numero1
# SE numero4 > numero2 E numero4 < numero3
#     ESCREVA “A ordem decrescente é: “,numero3,“-”,numero4,“-”,numero2,“-”,numero1
# SE numero4 > numero1 E numero4 < numero2
#     ESCREVA “A ordem decrescente é: “,numero3,“-”,numero2,“-”,numero4, “-”,numero1
# SE numero4 < numero1
#     ESCREVA “A ordem decrescente é: “,numero3,“-”,numero2,“-”,numero1,“-”,numero4
# ```

# %%
# 5. Faça um programa que receba três números obrigatoriamente em ordem crescente e um quarto número que não siga essa regra. Mostre, em seguida, os quatro números em ordem decrescente. 
print("Escreva três números em ordem crescente e um quarto número de qualquer magnitude diferente dos anteriores:")
n1 = float(input())
n2 = float(input())
n3 = float(input())
n4 = float(input())
if n4<n1:
  print("A ordem decrescente é: {0}, {1}, {2} e {3}." .format(n3,n2,n1,n4))
elif n4>n1 and n4<n2:
  print("A ordem decrescente é: {0}, {1}, {2} e {3}." .format(n3,n2,n4,n1))
elif n4>n2 and n4<n3:
  print("A ordem decrescente é: {0}, {1}, {2} e {3}." .format(n3,n4,n2,n1))
else:
  print("A ordem decrescente é: {0}, {1}, {2} e {3}." .format(n4,n3,n2,n1))
# Out:
# Escreva três números em ordem crescente e um quarto número de qualquer magnitude diferente dos anteriores:
# 10
# 20
# 30
# 5
# Números em ordem decrescente: 30.0, 20.0, 10.0 e 5.0.

# %% [markdown]
# ### 6. Faça um programa que receba um número inteiro e verifique se é par ou ímpar.
#
# ```code
# ESCREVA “Digite um número: “
# LEIA numero
#
# resto = numero % 2
# SE resto == 0
#     ESCREVA “O número é par”
# SENÃO
#     ESCREVA “O número é ímpar”
# ```

# %%
# 6. Faça um programa que receba um número inteiro e verifique se é par ou ímpar.
numero = int(input("Informe um número: "))
if numero % 2 == 0 and numero != 0: # o conteúdo "numero % 2" é um cálculo simples, então não precisa de parenteses
  print("O número {0} é par." .format(numero))
elif numero % 2 != 0:
  print("O número {0} é ímpar." .format(numero))
else:
  print("O número digitado é 0.")
# Out:
# Informe um número: 9
# O número 9 é ímpar.

# %% [markdown]
# ### 7. Faça um programa que receba quatro valores: I, A, B e C. Desses valores, I é inteiro e positivo, A, B e C são reais. Escreva os números A, B e C obedecendo à tabela a seguir.
#
# *Suponha que o valor digitado para I seja sempre um valor válido, ou seja, 1, 2 ou 3, e que os números digitados sejam diferentes um do outro.*
#
#   |VALOR DE I | FORMA A ESCREVER|
#   |---|---|
#   |1|A, B e C em ordem crescente.|
#   |2|A, B e C em ordem decrescente|
#   |3|O maior fica entre os outros dois números.|
#
#   ```code
# ESCREVA “Digite um valor para A:”
# LEIA A
# ESCREVA “Digite um valor para B:”
# LEIA B
# ESCREVA “Digite um valor para C:”
# LEIA C
# ESCREVA “Digite um valor para I (1, 2 ou 3):”
# LEIA I
#
# SE I == 1
#     SE A<B E A<C
#         SE B<C
#             ESCREVA “A ordem crescente dos números é:”,A,” -”,B,”-”,C
#         SENÃO
#         ESCREVA “A ordem crescente dos números é:”,A,” -”,C,”-”,B
#     SE B<A E B<C
#         SE A<C
#             ESCREVA “A ordem crescente dos números é:”,B,”-”,A,”-”,C
#         SENÃO
#             ESCREVA “A ordem crescente dos números é: “,B,”-”,C,”-”,A
#     SE C<A E C<B
#         SE A<B
#             ESCREVA “A ordem crescente dos números é: “,C,”-”,A,”-”,B
#         SENÃO
#             ESCREVA “A ordem crescente dos números é: “,C,”-”,B,”-”,A
# SE I == 2
#     SE A>B E A>C
#         SE B>C
#             ESCREVA “A ordem decrescente dos números é: “,A,” -”,B,”-”,C
#         SENÃO
#             ESCREVA “A ordem decrescente dos números é: “,A,” -”,C,”-”,B
#     SE B>A E B>C
#         SE A>C
#             ESCREVA “A ordem decrescente dos números é: “,B,” -”,A,”-”,C
#         SENÃO
#             ESCREVA “A ordem decrescente dos números é: “,B,” -”,C,”-”,A
#     SE C>A E C>B
#         SE A>B
#             ESCREVA “A ordem decrescente dos números é: “,C,” -”,A,”-”,B
#         SENÃO
#             ESCREVA “A ordem decrescente dos números é: “,C,” -”,B,”-”,A
# SE I == 3
#     SE A>B E A>C
#         ESCREVA “A ordem desejada é: “,B,”-”,A,”-”,C
#     SE B>A E B>C
#         ESCREVA “A ordem desejada é: “,A,”-”,B,”-”,C
#     SE C>A E C>B
#         ESCREVA “A ordem desejada é: “,A,”-”,C,”-”,B
# ```

# %%
# 7. Faça um programa que receba quatro valores: I, A, B e C. Desses valores, I é inteiro e positivo, A, B e C são reais. Escreva os números A, B e C obedecendo à tabela a seguir.
print("Digite três números diferentes: ")
A = float(input())
B = float(input())
C = float(input())
I = int(input("Digite o número de uma das opções: \n1 : Ordem crescente \n2 : Ordem decrescente ou \n3 : O maior número fica entre os outros dois \nOpção: "))
if I == 1:
  if A > B and A > C:
    if B > C:
      print("A ordem crescente dos números é: {0}, {1} e {2}." .format(C,B,A))
    else:
      print("A ordem crescente dos números é: {0}, {1} e {2}." .format(B,C,A))
  elif B > A and B > C:
    if A > C:
      print("A ordem crescente dos números é: {0}, {1} e {2}." .format(C,A,B))
    else:
      print("A ordem crescente dos números é: {0}, {1} e {2}." .format(A,C,B))
  elif C > A and C > B:
    if A > B:
      print("A ordem crescente dos números é: {0}, {1} e {2}." .format(B,A,C))
    else:
      print("A ordem crescente dos números é: {0}, {1} e {2}." .format(A,B,C))  
if I == 2:
  if A > B and A > C:
    if B > C:
      print("A ordem decrescente dos números é: {0}, {1} e {2}." .format(A,B,C))
    else:
      print("A ordem decrescente dos números é: {0}, {1} e {2}." .format(A,C,B))
  elif B > A and B > C:
    if A > C:
      print("A ordem decrescente dos números é: {0}, {1} e {2}." .format(B,A,C))
    else:
      print("A ordem decrescente dos números é: {0}, {1} e {2}." .format(B,C,A))
  elif C > A and C > B:
    if A > B:
      print("A ordem decrescente dos números é: {0}, {1} e {2}." .format(C,A,B))
    else:
      print("A ordem decrescente dos números é: {0}, {1} e {2}." .format(C,B,A))
if I == 3:
  if A > B and A > C:
    print("{0}, {1} e {2}." .format(B,A,C))
  elif B > A and B > C:
    print("{0}, {1} e {2}." .format(A,B,C))
  else:
    print("{0}, {1} e {2}." .format(A,C,B))
# Out:
# Digite três números diferentes:
# 56
# 45
# 64
# Digite o número de uma das opções:
# 1 : Ordem crescente
# 2 : Ordem decrescente ou
# 3 : O maior número fica entre os outros dois
# Opção: 2
# A ordem decrescente dos números é: 64.0, 56.0 e 45.0.

# %% [markdown]
# ### 8. Faça um programa que mostre o menu de opções a seguir, receba a opção do usuário e os dados necessários para executar cada operação.
#
#     Menu de opções:
#     1. Somar dois números.
#     1. Raiz quadrada de um número.
#
#     Digite a opção desejada:
#   ```code
#   ESCREVA “ MENU”
#   ESCREVA “1- Somar dois números”
#   ESCREVA “2- Raiz quadrada de um número”
#   ESCREVA “Digite sua opção: “
#   LEIA opcao
#
#   SE opcao == 1
#       ESCREVA “Digite um valor para o primeiro número:”
#       LEIA numeroero1
#       ESCREVA “Digite um valor para o segundo número:”
#       LEIA numero2
#       soma = numero1 + numero2
#       ESCREVA “A soma de “,num1,” e “,num2,” é “,soma
#
#   SE opcao == 2
#       ESCREVA “Digite um valor: “
#       LEIA numero1
#       raiz = numero ** 1/2
#       ESCREVA “A raiz quadrada de “,num1,” é “,raiz
#
#   SE opcao != 1 E opcao != 2
#       ESCREVA “Opção inválida!”
#   ```

# %%
# 8. Faça um programa que mostre o menu de opções a seguir, receba a opção do usuário e os dados necessários para executar cada operação. 
print("Menu de opções:")
print("1. Somar dois números.")
print("2. Raiz quadrado de um número.")
opcao = int(input("Qual a sua opção? 1 ou 2? "))
if opcao == 1:
  print("Informe os números que deseja somar: ")
  n1 = float(input())
  n2 = float(input())
  soma = n1 + n2
  print("A soma dos números {0} e {1} é {2}." .format(n1,n2,soma))
elif opcao == 2:
  print("Informe o número de que deseja saber a raiz quadrada: ")
  n1 = float(input())
  raiz = n1 ** 2
  print("A raiz quadrada do número {0} é {1}." .format(n1,raiz))
else:
  print("Por favor, reinicie o programa e digite umas das opções do menu.")
# Out:
# Menu de opções:
# 1. Somar dois números.
# 2. Raiz quadrado de um número.
# Qual a sua opção? 1 ou 2? 2
# Informe o número de que deseja saber a raiz quadrada:
# 5
# A raiz quadrada do número 5.0 é 25.0.

# %% [markdown]
# ### 9. Faça um programa que mostre a data e a hora do sistema nos seguintes formatos: DD/MM/AAAA – mês por extenso e hora:minuto.
#
# *Para saber como obter a data e hora em Python [leia este artigo](https://pythonhelp.wordpress.com/2011/11/05/obtendo-a-data-e-a-hora-atuais-em-python/)*
#
# ```code
# data = OBTENHA_DATA;
# dia = OBTENHA_DIA(d)
# mes = OBTENHA_MÊS(d)
# ano = OBTENHA_ANO(d)
#
# ESCREVA “Data Atual: “ , dia, “/”, mes, “/”, ano, “ – ”
#
# SE mes == 1
#     ESCREVA “janeiro”
# SE mes == 2
#     ESCREVA “fevereiro”
# SE mes == 3
#     ESCREVA “março”
# SE mes == 4
#     ESCREVA “abril”
# SE mes == 5
#     ESCREVA “maio”
# SE mes == 6
#     ESCREVA “junho”
# SE mes == 7
#     ESCREVA “julho”
# SE mes == 8
#     ESCREVA “agosto”
# SE mes == 9
#     ESCREVA “setembro”
# SE mes == 10
#     ESCREVA “outubro”
# SE mes == 11
#     ESCREVA “novembro”
# SE mes == 12
#     ESCREVA “dezembro”
#
# tempo = OBTENHA_HORÁRIO;
# hora = OBTENHA_HORA(tempo)
# min = OBTENHA_MINUTO(tempo)
#
# ESCREVA “Hora Atual: “
# ESCREVA hora, “:” , min
# ```

# %%
# 9. Faça um programa que mostre a data e a hora do sistema nos seguintes formatos: DD/MM/AAAA – mês por extenso e hora:minuto.
from datetime import datetime
agora = datetime.now()
if agora.month == 1:
  mes = "janeiro"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 2:
  mes = "fevereiro"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 3:
  mes = "março"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 4:
  mes = "abril"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 5:
  mes = "maio"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 6:
  mes = "junho"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 7:
  mes = "julho"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 8:
  mes = "agosto"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 9:
  mes = "setembro"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 10:
  mes = "outubro"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 11:
  mes = "novembro"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
elif agora.month == 12:
  mes = "dezembro"
  print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes,agora.hour,agora.minute))
# Out:
# Hoje é 24/09/2019 (24 de setembro de 2019). Hora atual: 15:02.

# %%
# 9. Faça um programa que mostre a data e a hora do sistema nos seguintes formatos: DD/MM/AAAA – mês por extenso e hora:minuto.
from datetime import datetime
agora = datetime.now()
mes = ('janeiro','fevereiro','março','abril','maio','junho','julho','agosto','setembro','outubro','novembro','dezembro')
print("Hoje é {0:02d}/{1:02d}/{2} ({0:02d} de {3!s} de {2}). Hora atual: {4:02d}:{5:02d}." .format(agora.day,agora.month,agora.year,mes[agora.month-1],agora.hour,agora.minute))
# Out:
# Hoje é 24/09/2019 (24 de setembro de 2019). Hora atual: 15:02.

# %% [markdown]
# ### 10. Faça um programa que determine a data cronologicamente maior entre duas datas fornecidas pelo usuário. Cada data deve ser composta por três valores inteiros, em que o primeiro representa o dia, o segundo, o mês e o terceiro, o ano.
#
#   ```code
#   ESCREVA “Digite a primeira data”
#   ESCREVA “ dia (dd): “
#   LEIA dia1
#
#   ESCREVA “ mês (mm): “
#   LEIA mes1
#   ESCREVA “ ano (aaaa): “
#   LEIA ano1
#
#   ESCREVA “Digite a segunda data”
#   ESCREVA “ dia (dd): “
#   LEIA dia2
#
#   ESCREVA “ mês (mm): “
#   LEIA mes2
#
#   ESCREVA “ ano (aaaa): “
#   LEIA ano2
#
#   SE ano1 > ano2
#       ESCREVA “A maior data é: “,dia1,”-”,mes1,”-”,ano1
#   SENÃO SE ano2>ano1
#       ESCREVA “A maior data é: “,dia2,”-”,mes2,”-”,ano2
#   SENÃO SE mes1>mes2
#       ESCREVA “A maior data é: “,dia1,”-”,mes1,”-”,ano1
#   SENÃO SE mes2>mes1
#       ESCREVA “A maior data é: “,dia2, “-”,mes2,”-”,ano2
#   SENÃO SE dia1>dia2
#       ESCREVA “A maior data é: “-”,dia1,”-”,mia1,” -”,ano1
#   SENÃO SE dia2>dia1
#       ESCREVA “A maior data é: “,dia2,” -”,mes2,”-”,ano2
#   SENÃO
#       ESCREVA “As datas são iguais!”
#
#   ```

# %%
# 10. Faça um programa que determine a data cronologicamente maior entre duas datas fornecidas pelo usuário. Cada data deve ser composta por três valores inteiros, em que o primeiro representa o dia, o segundo, o mês e o terceiro, o ano.
print("Informe a primeira data:")
dia1 = int(input("Dia (dd):"))
mes1 = int(input("Mês (mm):"))
ano1 = int(input("Ano (aaaa):"))
print("\nInforme a segunda data:")
dia2 = int(input("Dia (dd):"))
mes2 = int(input("Mês (mm):"))
ano2 = int(input("Ano (aaaa):"))
if ano1 > ano2:
  print("\nA data mais recente é {0:02d}/{1:02d}/{2}." .format(dia1,mes1,ano1))
elif ano2 > ano1:
  print("\nA data mais recente é {0:02d}/{1:02d}/{2}." .format(dia2,mes2,ano2))
else:
  if mes1 > mes2:
    print("\nA data mais recente é {0:02d}/{1:02d}/{2}." .format(dia1,mes1,ano1))
  elif mes2 > mes1:
    print("\nA data mais recente é {0:02d}/{1:02d}/{2}." .format(dia2,mes2,ano2))
  else:
    if dia1 > dia2:
      print("\nA data mais recente é {0:02d}/{1:02d}/{2}." .format(dia1,mes1,ano1))
    elif dia2 > dia1:
      print("\nA data mais recente é {0:02d}/{1:02d}/{2}." .format(dia2,mes2,ano2))
    else:
      print("\nAs datas são iguais.")
# Out:
# Informe a primeira data:
# Dia (dd):01
# Mês (mm):1
# Ano (aaaa):2019
#
# Informe a segunda data:
# Dia (dd):02
# Mês (mm):03
# Ano (aaaa):1998
#
# A data mais recente é 01/01/2019.

# %% [markdown]
# ### 11. Faça um programa que receba a hora do início de um jogo e a hora do término (cada hora é composta por duas variáveis inteiras: hora e minuto). Calcule e mostre a duração do jogo (horas e minutos), sabendo que o tempo máximo de duração do jogo é de 24 horas e que ele pode começar em um dia e terminar no dia seguinte.
#
#   ```code
#   ESCREVA “Digite o horário inicial”
#
#   ESCREVA “hora: "
#   LEIA hora_inicial
#
#   ESCREVA “minuto: “
#   LEIA minuto_inicial
#
#   ESCREVA “Digite o horário final “
#
#   ESCREVA “hora: “
#   LEIA hora_final
#
#   ESCREVA “minuto: “
#   LEIA minuto_final
#
#   SE min_inicial > min_f
#       minuto_final = minuto_final + 60
#       hora_final = hora_final – 1
#
#   SE hora_inicial > hora_final
#       hora_final - hora_final + 24
#
#   minuto_duracao = minuto_final - minuto_inicial;
#   hora_duracao = hora_final - hora_inicial;
#
#   ESCREVA “O jogo durou “,hora_duracao,” hora(s) e “,min_duracao,” minuto(s)”
#   ```

# %%
# 11. Faça um programa que receba a hora do início de um jogo e a hora do término (cada hora é composta 
print("Informe a hora de início e de término do jogo:")
horaInic = int(input("\nQual a hora de início? (HH): "))
minInic = int(input("Qual o minuto de início? (mm): "))
horaFin = int(input("\nQual a hora de término? (HH): "))
minFin = int(input("Qual o minuto de término? (mm): "))

if horaFin > horaInic:
  # 03:00 às 23:00
  totalMinInic = (horaInic * 60) + minInic
  totalMinFin = (horaFin * 60) + minFin
  duracaototal = totalMinFin - totalMinInic
  duracaoH = duracaototal // 60
  duracaoMin = duracaototal % 60
  print("\nA duração do jogo foi de {0:02d}:{1:02d} ({0:02d} hora(s) e {1:02d} minuto(s))." .format(duracaoH,duracaoMin))
elif horaInic > horaFin:
  # 23:00 às 03:00
  horaInic = (horaInic - 24) * (-1) 
  totalMinInic = horaInic - minInic
  totalMinFin = (horaFin * 60) + minFin
  duracaototal = totalMinInic + totalMinFin
  duracaoH = duracaototal // 60
  duracaoMin = duracaototal % 60 - 1
  #print("duracaoMin",duracaoMin)
  print("\nA duração do jogo foi de {0:02d}:{1:02d} ({0:02d} hora(s) e {1:02d} minuto(s))." .format(duracaoH,duracaoMin))  
else:
  print("\nVocê digitou algum número errado!")
# Out:
# Informe a hora de início e de término do jogo:
#
# Qual a hora de início? (HH): 23
# Qual o minuto de início? (mm): 30
#
# Qual a hora de término? (HH): 4
# Qual o minuto de término? (mm): 0
#
# A duração do jogo foi de 03:30 (03 hora(s) e 30 minuto(s)).

# %% [markdown]
# ### 12. Faça um programa que receba o código correspondente ao cargo de um funcionário e seu salário atual e mostre o cargo, o valor do aumento e seu novo salário. Os cargos estão na tabela a seguir.
#
#   |CÓDIGO|CARGO|PERCENTUAL|
#   |---|---|---|
#   |1|Escriturário|50%|
#   |2|Secretário|35%|
#   |3|Caixa|20%|
#   |4|Gerente|10%|
#   |5|Diretor|Não tem aumento|
#
# ```code
# ESCREVA “Digite o cargo do funcionário (1,2,3,4 ou 5)”
# LEIA cargo
#
# ESCREVA “Digite o valor do salário: “
# LEIA salario
#
# SE cargo == 1
#     ESCREVA “O cargo é Escriturário”
#     aumento = salario * 50 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “, novo_sal
#
# SENÃO SE cargo == 2
#     ESCREVA “O cargo é Secretário”
#     aumento = salario * 35 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “, novo_sal]
#
# SENÃO SE cargo == 3
#     ESCREVA “O cargo é Caixa”
#     aumento = salario * 20 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “,novo_sal
#
# SENÃO SE cargo == 4
#     ESCREVA “O cargo é Gerente”
#     aumento = salario * 10 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “, novo_sal
#
# SENÃO SE cargo == 5
#     ESCREVA “O cargo é Diretor”
#     aumento = salario * 0 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “, novo_sal
#
# SENÃO
#     ESCREVA “Cargo Inexistente !”
# ```

# %%
# 12. Faça um programa que receba o código correspondente ao cargo de um funcionário e seu salário
#def aumento():
#  if codCargo != 5:
#    aumento = salAtual * percAumento
#    salNovo = salAtual + aumento
#    print("O {0}, com salário atual de R$ {1:.2f}, teve aumento de R$ {2:.2f} e seu novo salário é R$ {3:.2f}." .format(cargo,salAtual,aumento,salNovo))

print("Informe algum dos códigos a seguir correspondente ao cargo para saber informações sobre salário e aumento.")
print("1. Escriturário")
print("2. Secretário")
print("3. Caixa")
print("4. Gerente")
print("5. Diretor")
codCargo = int(input("\nCódigo: "))
salAtual = float(input("Informe o salário atual: R$ "))
if codCargo == 1:
  cargo = ("Escriturário")
  percAumento = 0.5
  aumento = salAtual * percAumento
  salNovo = salAtual + aumento
  print("\nO {0}, com salário atual de R$ {1:.2f}, teve aumento de R$ {2:.2f} e seu novo salário é R$ {3:.2f}." .format(cargo,salAtual,aumento,salNovo))
#  aumento()
elif codCargo == 2:
  cargo = ("Secretário")
  percAumento = 0.35
  aumento = salAtual * percAumento
  salNovo = salAtual + aumento
  print("\nO {0}, com salário atual de R$ {1:.2f}, teve aumento de R$ {2:.2f} e seu novo salário é R$ {3:.2f}." .format(cargo,salAtual,aumento,salNovo))
#  aumento()
elif codCargo == 3:
  cargo = ("Caixa")
  percAumento == 0.2
  aumento = salAtual * percAumento
  salNovo = salAtual + aumento
  print("\nO {0}, com salário atual de R$ {1:.2f}, teve aumento de R$ {2:.2f} e seu novo salário é R$ {3:.2f}." .format(cargo,salAtual,aumento,salNovo))
#  aumento()
elif codCargo == 4:
  cargo = ("Gerente")
  percAumento = 0.1
  aumento = salAtual * percAumento
  salNovo = salAtual + aumento
  print("\nO {0}, com salário atual de R$ {1:.2f}, teve aumento de R$ {2:.2f} e seu novo salário é R$ {3:.2f}." .format(cargo,salAtual,aumento,salNovo))
#  aumento()
elif codCargo == 5:
  cargo = ("Diretor")
  print("\nO {0}, com salário atual de R$ {1:.2f}, não teve aumento."  .format(cargo,salAtual))
else:
  print("\nCódigo inválido.")
# Out:
# Informe algum dos códigos a seguir correspondente ao cargo para saber informações sobre salário e aumento.
# 1. Escriturário
# 2. Secretário
# 3. Caixa
# 4. Gerente
# 5. Diretor
#
# Código: 3
# Informe o salário atual: R$ 1000
#
# O Caixa, com salário atual de R$ 1000.00, teve aumento de R$ 100.00 e seu novo salário é R$ 1100.00.

# %% [markdown]
# ### 13. Faça um programa que apresente o menu a seguir, permita ao usuário escolher a opção desejada, receba os dados necessários para executar a operação e mostre o resultado. Verifique a possibilidade de opção inválida e não se preocupe com restrições, como salário negativo.
#
#     Menu de opções:
#     1. Imposto
#     2. Novo salário
#     3. Classificação
#
#     Digite a opção desejada:
#
# *Na opção 1: receber o salário de um funcionário, calcular e mostrar o valor do imposto usando as regras a seguir.*
#
#   |SALÁRIO|PERCENTUAL DO IMPOSTO|
#   |---|---|
#   |Menor que  500,00|5%|
#   |De  500,00 (inclusive) a  850,00 (inclusive)|10%|
#   |Acima de  850,00|15%|
#
# *Na opção 2: receber o salário de um funcionário, calcular e mostrar o valor do novo salário, usando as regras a seguir.*
#
#   |SALÁRIO|AUMENTO|
#   |---|---|
#   |Maior que  1.500,00| 25,00|
#   |De  750,00 (inclusive) a  1.500,00 (inclusive)| 50,00|
#   |De  450,00 (inclusive) a  750,00| 75,00|
#   |Menor que  450,00| 100,00|
#
# *Na opção 3: receber o salário de um funcionário e mostrar sua classificação usando a tabela a seguir.*
#
# |SALÁRIO|CLASSIFICAÇÃO|
# |---|---|
# |Até  700,00 (inclusive)|Mal remunerado|
# |Maiores que  700,00|Bem remunerado|
#
# ```code
# ESCREVA “MENU DE OPÇÕES”
# ESCREVA “1 – IMPOSTO”
# ESCREVA “NOVO SALÁRIO”
# ESCREVA “CLASSIFICAÇÃO”
#
# ESCREVA “DIGITE A OPÇÃO DESEJADA”
# LEIA operacao
#
# SE operacao = 1
#       LEIA salario
#       SE salario < 500
#           imposto = salario * 5/100
#       SE salario >= 500 E salario <= 850
#           imposto = salario * 10/100
#       SE salario > 850
#           imposto = salario * 15/100
#       ESCREVA imposto
#
# SE operacao = 2
#     LEIA salario
#     SE salario > 1500
#         aumento = 25
#     SE salario >= 750 E salario <= 1500
#         aumento = 50
#     SE salario >= 450 E salario < 750
#         aumento = 75
#     SE salario < 450
#         aumento = 100 novo_salario = salario + aumento
#     ESCREVA novo_salario
#
# SE operacao = 3
#     LEIA salario
#     SE salario <= 700
#         ESCREVA”Mal Remunerado”
#     SE salario > 700
#         ESCREVA”Bem Remunerado”
#
# SE operacao < 1 OU operacao > 3
#     ENTÃO ESCREVA “Opção Inválida”
#
# ```

# %%
# 13. Faça um programa que apresente o menu a seguir, permita ao usuário escolher a opção desejada, receba os dados necessários para executar a operação e mostre o resultado. 
print("Menu de opções:")
print("1. Imposto")
print("2. Novo salário")
print("3. Classificação")
codMenu = int(input("\nInforme a opção desejada: "))
if codMenu == 1:
  salAtual = float(input("Informe o salário atual: R$ "))
  if salAtual < 500:
    imposto = salAtual * 0.05
  elif salAtual <= 850:
    imposto = salAtual * 0.1
  else:
    imposto = salAtual * 0.15
  print("\nO valor do imposto para o salário de R$ {0:.2f} é R$ {1:.2f}." .format(salAtual,imposto))
if codMenu == 2:
  salAtual = float(input("Informe o salário atual: R$ "))
  if salAtual < 450:
    aumento = 100
  elif salAtual <= 750:
    aumento = 75
  elif salAtual <=1500:
    aumento = 50
  else:
    aumento = 25
  salNovo = salAtual + aumento
  print("\nO nome salário, considerando o aumento de R$ {0:.2f}, é R$ {1:.2f}." .format(aumento,salNovo))
if codMenu == 3:
  salAtual = float(input("Informe o salário atual: R$ "))
  if salAtual <= 700:
    classif = "mal remunerado"
  else:
    classif = "bem remunerado"
  print("\nCom o salário atual de R$ {0:.2f}, o funcionário é considerado '{1}'." .format(salAtual,classif))
if codMenu < 1 or codMenu > 3:
  print("\nOpção inválida!")
# Out:
# Menu de opções:
# 1. Imposto
# 2. Novo salário
# 3. Classificação
#
# Informe a opção desejada: 2
# Informe o salário atual: R$ 1000
#
# O nome salário, considerando o aumento de R$ 50.00, é R$ 1050.00.

# %% [markdown]
# ### 14. Faça um programa que receba o salário inicial de um funcionário, calcule e mostre o novo salário, acrescido de bonificação e de auxílio escola.
#
# |SALÁRIO|BONIFICAÇÃO|
# |---|---|
# |Até  500,00|5% do salário|
# |Entre  500,00 e 1.200,00|12% do salário|
# |Acima de  1.200,00|Sem bonificação|
#
# >
#
# |SALÁRIO|AUXÍLIO ESCOLA|
# |---|---|
# |Até  600,00| 150,00|
# |Acima de  600,00| 100,00|
#
# ```code
# LEIA salario
# SE salario <= 500
#     bonificacao = salario * 5/100
# SE salario <= 1200
#     bonificacao = 0
# SENÃO bonificacao = 12 /100
#
# SE salario <= 600
#     aux = 150
# SENÃO aux = 100
#
# novo_salario = salario + bonificacao + aux
# ESCREVA novo_salario
# ```

# %%
# 14. Faça um programa que receba o salário inicial de um funcionário, calcule e mostre o novo salário, acrescido de bonificação e de auxílio escola.
#def auxEscola(auxEscola):
#  if salario < 600:
#    return 150
#  else:
#    return 100
#
salario = float(input("Informe o salário base: R$ "))
if salario < 500:
  alBonif = 5/100 # alBonif é a alíquota da bonificação
  bonif = salario * alBonif
elif salario <= 1200:
  alBonif = 12/100
  bonif = salario * alBonif
else:
  bonif = 0
if salario <600:
  auxEscola = 150
else:
  auxEscola = 100   
salNovo = salario + bonif + auxEscola
print("O novo salário é R$ {0:.2f}, acrescido de uma bonificação de R$ {1:.2f} e um auxílio escola de R$ {2:.2f}." .format(salNovo,bonif,auxEscola))
# Out:
# Informe o salário base: R$ 1500
# O novo salário é R$ 1600.00, acrescido de uma bonificação de R$ 0.00 e um auxílio escola de R$ 100.00.

# %% [markdown]
# ### 15. Faça um programa que receba o valor do salário mínimo, o número de horas trabalhadas, o número de dependentes do funcionário e a quantidade de horas extras trabalhadas. Calcule e mostre o salário a receber do funcionário de acordo com as regras a seguir:
#
#   * O valor da hora trabalhada é igual a 1/5 do salário mínimo.
#   * O salário do mês é igual ao número de horas trabalhadas multiplicado pelo valor da hora trabalhada.
#   * Para cada dependente, acrescentar  32,00.
#   * Para cada hora extra trabalhada, calcular o valor da hora * trabalhada acrescida de 50%.
#   * O salário bruto é igual ao salário do mês mais o valor dos dependentes mais o valor das horas extras.
#   * Calcular o valor do impostoosto de renda retido na fonte de acordo com a tabela a seguir:
#
# |IRFF|SALÁRIO BRUTO|
# |---|---|
# |Isento|Inferior a  200,00|
# |10%|De  200,00 até 500,00|
# |20%|Superior a  500,00|
#
#   * O salário líquido é igual ao salário bruto menos IRRF.
#   * A gratificação é de acordo com a tabela a seguir:
#
# |SALÁRIO LÍQUIDO|GRATIFICAÇÃO|
# |---|---|
# |Até 350,00| 100,00|
# |Superior a  350| 50,00|
#
#   * O salário a receber do funcionário é igual ao salário líquido mais a gratificação.
#
#   ```code
#   LEIA salario_minimo, numero_de_horas_trabalhadas, numero_de_dependentes, numero_de_horas_extras
#
#   valor_da_hora = 1/5 * salario_minimo
#  salario_do_mes = numero_de_horas_trabalhadas * valor_da_hora
#   valor_dos_dependentes = 32 * numero_de_dependentes
#   valor_da_hora_extra = numero_de_horas_extras * (valor_da_hora + (valor_da_hora * 50/100))
#   salario_bruto =salario_do_mes + valor_dos_dependentes + valor_da_hora_extra
#
#   SE salario_bruto < 200
#         ENTÃO imposto = 0
#   SE salario_bruto >= 200 E salario_bruto <= 500
#         ENTÃO imposto = salario_bruto * 10/100
#   SE salario_bruto > 500
#        ENTÃO imposto = salario_bruto * 20/100
#   salario_liquido = salario_bruto – imposto
#   SE salario_liquido <= 350
#         ENTÃO gratificacao = 100
#   SE salario_liquido > 350
#         ENTÃO gratificacao = 50
#   salario_a_receber = salario_liquido + gratificacao
#
#   ESCREVA salario_a_receber
#   ```

# %%
# 15. Faça um programa que receba o valor do salário mínimo, o número de horas trabalhadas, o número de dependentes do funcionário e a quantidade de horas extras trabalhadas. Calcule e mostre o salário a receber do funcionário
salMin = float(input("Informe o valor do salário mínimo: R$ "))
qt_horTrab = float(input("Qual a quantidade de horas trabalhadas? "))
numDep = int(input("Qual o número de dependentes? " ))
qt_horExtra = float(input("Qual a quantidade de horas extras trabalhadas? "))
vl_horTrab = salMin / 5
salMes = qt_horTrab * vl_horTrab
adDep = numDep * 32
vl_horExtra = vl_horTrab * 1.5
salExtra = vl_horExtra * qt_horExtra
salBruto = salMes + adDep + salExtra
if (salBruto - 200) > 0:
    irff = 0
    salBrutoIRFF = salBruto - 200
else:
    irff = 0
if (salBrutoIRFF - 500) > 0:
    irff = irff + 50
    salBrutoIRFF = salBrutoIRFF - 500
else:
    irff = irff + salBrutoIRFF * 0.1
if salBrutoIRFF > 0:
    irff = irff + salBrutoIRFF * 0.2
salLiqIRFF = salBruto - irff
if salLiqIRFF < 100:
    grat = 100
else:
    grat = 50
salLiq = salLiqIRFF + grat
print("O salário líquido a receber pelo funcionário é R$ {0:.2f}." .format(salLiq))     
#print("O salário base do mês é R$ {0:.2f}." .format(salMes))    
#print("O salário extra é R$ {0:.2f}." .format(salExtra))  
#print("O adicional por dependentes é R$ {0:.2f}." .format(adDep))
#print("O salário bruto do mês é R$ {0:.2f}." .format(salBruto))
#print("O valor do IRRF do mês é R$ {0:.2f}." .format(irff))
#print("O valor da gratificação no mês é R$ {0:.2f}." .format(grat))
#print("O salário líquido a receber pelo funcionário é R$ {0:.2f}." .format(salLiq))
# Out:
# Informe o valor do salário mínimo: R$ 1000
# Qual a quantidade de horas trabalhadas? 20
# Qual o número de dependentes? 2
# Qual a quantidade de horas extras trabalhadas? 2
# O salário líquido a receber pelo funcionário é R$ 3871.20.

# %% [markdown]
# ### 16. Um supermercado deseja reajustar os preços de seus produtos usando o seguinte critério: o produto poderá ter seu preço aumentado ou diminuído. Para o preço ser alterado, o produto deve preencher pelo menos um dos requisitos a seguir:
#
# |VENDA MÉDIA MENSAL|PREÇO ATUAL|% DE AUMENTO|% DE DIMINUIÇÃO|
# |---|--|---|---|
# |< 500|<  30.000|10|-|
# |\>= 500 e <1.200|\>=  30,00 e <  80,00|15|-|
# |\>= 1,200|\>=  80,00|-|20|
#
# * Faça um programa que receba o preço atual e a venda média mensal do produto, calcule e mostre o novo preço.
#
# ```code
# LEIA preco_atual, media_mensal_de_vendas
#
# SE media_mensal_de_vendas < 500 OU preco_atual < 30
#     novo_preco = preco_atual + 10/100 * preco_atual
# SENÃO SE media_mensal_de_vendas >= 500 E media_mensal_de_vendas < 1200 OU preco_atual >= 30 E preco_atual<80
#     ENTÃO novo_preco = preco_atual + 15 / 100 * preco_atual
# SENÃO SE venda >= 1200 OU preco_atual >= 80
#     ENTÃO novo_preco = preco_atual – 20 / 100 * preco_atual
#
# ESCREVA novo_preco
# ```

# %%
# 16. Faça um programa que receba o preço atual e a venda média mensal do produto, calcule e mostre o novo preço.
precoProd = float(input("Informe o preço atual do produto: R$ "))
medVendaMes = int(input("Qual a quantidade média mensal de venda do produto? " ))
if medVendaMes < 500 and precoProd < 30:
    precoProd = precoProd * 1.1
elif 500 <= medVendaMes < 1200 and 30 <= precoProd < 80:
    precoProd = precoProd * 1.15
elif medVendaMes >= 1200 and precoProd >= 80:
    precoProd = precoProd * 0.80
else:
    print("O produto não terá o preço reajustado.")
print("O novo preço do produto é R$ {0:.2f}." .format(precoProd))
# Out:
# Informe o preço atual do produto: R$ 50
# Qual a quantidade média mensal de venda do produto? 500
# O novo preço do produto é R$ 57.50.

# %% [markdown]
# ### 17. Faça um programa para resolver equações do 2 o grau.
#
# **ax² + bx + c = 0**
#
# *A variável a deve ser diferente de zero.*
#
#   * delta = b ** 2 - 4 * a * c
#   * delta < 0.  **Não existe raiz real**
#   * delta = 0. **Existe uma raiz real**
#     * x = (-b) / (2 * a)
#   * delta > 0. **Existem duas raízes reais**
#     * x1 = (-b + delta )/ (2 * a)
#     * x2 = (-b - delta )/ (2 * a)
#
#
# LEIA a, b, c
#
# SE a = 0
#
#     ESCREVA “Estes valores não formam uma equação de segundo grau”
#
# SENÃO
#
#     delta = (b * b) – ( 4 * a * c)
#
#     SE delta < 0
#
#         ENTÃO ESCREVA “Não existe raiz real”
#
#     SE delta = 0
#
#         ESCREVA “Existe uma raiz real”
#
#         x1 = (– b) / (2 * a)
#
#         ESCREVA x1
#
#     SE delta > 0
#
#         ESCREVA “Existem duas raízes reais”
#
#         x1 = (– b) + raiz(delta) / (2 * a)
#
#         x2 = (– b) - raiz(delta) / (2 * a)
#
#         ESCREVA(x1, x2)

# %%
# 17. Faça um programa para resolver equações do 2 o grau.
varA = float(input("Informe o valor de a: "))
varB = float(input("Informe o valor de b: "))
varC = float(input("Informe o valor de c: "))
delta = varB ** 2 - 4 * varA * varC
if delta < 0:
    print("Não existe raiz real.")
elif delta == 0:
    varX = (-varB)/(2*varA)
    print("Existem duas raizes reais que são idênticas e iguais a {0:.2f}." .format(varX))
else:
    varX1 = (-varB + delta)/(2*varA)
    varX2 = (-varB - delta)/(2*varA)
    print("Existem duas raizes reais que são iguais a {0:.2f} e {1:.2f}." .format(varX1,varX2))
# Out:
# Informe o valor de a: 1
# Informe o valor de b: 2
# Informe o valor de c: 1
# Existem duas raizes reais que são idênticas e iguais a -1.00.

# %% [markdown]
# ### 18. Dados três valores X, Y e Z, verifique se eles podem ser os comprimentos dos lados de um triângulo e, se forem, verifique se é um triângulo equilátero, isósceles ou escaleno. Se eles não formarem um triângulo, escreva uma mensagem.
#
# Considere que:
#
# * o comprimento de cada lado de um triângulo é menor que a soma dos outros dois lados;
# * chama-se equilátero o triângulo que tem três lados iguais;
# * denomina-se isósceles o triângulo que tem o comprimento de dois lados iguais;
# * recebe o nome de escaleno o triângulo que tem os três lados diferentes.
#
# ```code
# LEIA x, y, z
# SE x < y + z E y < x + z E z < x + y
#     SE x = y E y = z
#         ESCREVA “Triângulo Equilátero”
#     SENÃO SE x = y OU x = z OU y = z
#         ENTÃO ESCREVA “Triângulo Isósceles”
#     SENÃO SE x ≠ y E x ≠ z E y ≠ z
#         ENTÃO ESCREVA “Triângulo Escaleno”
# SENÃO
#     ESCREVA “Essas medidas não formam um triângulo”
# ```

# %%
# 18. Dados três valores X, Y e Z, verifique se eles podem ser os comprimentos dos lados de um triângulo e, se forem, verifique se é um triângulo equilátero, isósceles ou escaleno.
print("Informe o valor do comprimento dos três lados do triângulo.")
ladoA = float(input("1º lado: "))
ladoB = float(input("2º lado: "))
ladoC = float(input("3º lado: "))
if ladoA < (ladoB + ladoC) and ladoB < (ladoA + ladoC) and ladoC < (ladoA + ladoB):
    if ladoA == ladoB and ladoB == ladoC:
        print("Este triângulo é equilátero.")
    elif ladoA == ladoB or ladoA == ladoC or ladoB == ladoC:
        print("Este triângulo é isóseles.")
    else:
        print("Este triângulo é escaleno.")
else:
    print("Essas medidas não formam um triângulo.")
# Out:
# Informe o valor do comprimento dos três lados do triângulo.
# 1º lado: 10
# 2º lado: 5
# 3º lado: 10
# Este triângulo é isóseles.

# %% [markdown]
# ### 19. Faça um programa que receba a altura e peso de uma pessoa. De acordo com a tabela a seguir, verifique e mostre a classificação dessa pessoa.
#
# |ALTURA|ATÉ 60|ENTRE 60 E 90 (INCLUSIVE)|ACIMA DE 90|
# |---|---|---|---|
# |Menores que 1,20|A|D|G|
# |De 1,20 a 1,70|B|E|H|
# |Maiores que 1,70|C|F|I|
#
# ```code
# LEIA altura, peso
# SE altura < 1.20
#     SE peso <= 60
#         ENTÃO ESCREVA “A”
#     SE peso > 60 E peso <= 90
#         ENTÃO ESCREVA “D”
#     SE peso > 90
#         ENTÃO ESCREVA “G”
# SE altura >= 1.20 E altura <= 1.70
#     SE peso <= 60
#         ESCREVA “B”
#     SE peso > 60 E peso <= 90
#         ESCREVA “E”
#     SE peso > 90
#         ESCREVA “H”
# SE altura > 1.70
#     SE peso <= 60
#         ESCREVA “C”
#     SE peso > 60 E peso <= 90
#         EESCREVA “F”
#     SE peso > 90
#         ESCREVA “I”
# ```

# %%
# 19. Faça um programa que receba a altura e peso de uma pessoa. De acordo com a tabela a seguir, verifique e mostre a classificação dessa pessoa.
alt = float(input("Informe a altura (em metros): "))
peso = float(input("Informe o peso (em kg): "))
if alt < 1.2:
    if peso < 60:
        classif = "A"
    elif peso <= 90:
        classif = "D"
    else:
        classif = "G"
elif alt <= 1.7:
    if peso < 60:
        classif = "B"
    elif peso <= 90:
        classif = "E"
    else:
        classif = "H"
else:
    if peso < 60:
        classif = "C"
    elif peso <= 90:
        classif = "F"
    else:
        classif = "I"
print("Sua classificação é {0}." .format(classif))
# Out:
# Informe a altura (em metros): 2
# Informe o peso (em kg): 100
# Sua classificação é I.

# %% [markdown]
# ### 20. Faça um programa que receba:
#
# * O código de um produto comprado, supondo que a digitação do código do produto seja sempre válida, isto é, um número * inteiro entre 1 e 10.
# * O peso do produto em quilos.
# * O código do país de origem, supondo que a digitação do  código seja sempre válida, isto é, um número inteiro entre 1 e 3.
#
# |CÓDIGO DO PAÍS DE ORIGEM|IMPOSTO|
# |---|---|
# |1|0%|
# |2|15%|
# |3|25%|
#
# |CÓDIGO DO PAÍS DO PRODUTO|PREÇO POR GRAMA|
# |---|---|
# |1 a 4|10|
# |5 a 7|25|
# |8 a 10|35|
#
# Calcule e mostre:
#
# * o peso do produto convertido em gramas;
# * o preço total do produto comprado;
# * valor do imposto, sabendo que ele é cobrado sobre o * preço total do produto comprado e dependendo país de origem;
# * o valor total, preço total do produto mais imposto.
#
# ```code
# LEIA codigo_do_produto, peso_quilos, codigo_do_paiz
#
# peso_em_gramas = peso_quilos * 1000
# ESCREVA peso_em_gramas
#
# SE codigo_do_produto >= 1 E codigo_do_produto <= 4
#    preco_por_grama = 10
# SE codigo_do_produto >= 5 E codigo_do_produto <= 7
#    preco_por_grama = 25
# SE codigo_do_produto >= 8 E codigo_do_produto <= 10
#    preco_por_grama = 35
#
# preco_total = peso_em_gramas *preco_por_grama
# ESCREVA preco_total
#
# SE codigo_do_paiz = 1
#     imposto = 0
# SE codigo_do_paiz = 2
#     imposto = preco_total * 15/100
# SE codigo_do_paiz = 3
#     imposto = preco_total * 25/100
#
# ESCREVA imposto
#
# valor_total = preco_total + imposto
#
# ESCREVA valor_total
# ```

# %%
# 20. Faça um programa que receba:
print("Informe os seguintes dados para o cálculo do valor total do produto:")
codProd = int(input("Código do produto (de 1 a 10): "))
pesoProdKg = float(input("Peso do produto (em kg): "))
codPaisOrg = int(input("Código do país de origem do produto (de 1 a 3): "))
pesoProdGr = pesoProdKg * 1000
if codProd <= 4:
  precoPGr = 10
  precoTot = pesoProdGr * precoPGr
elif codProd <=7:
  precoPGr = 25
  precoTot = pesoProdGr * precoPGr 
elif codProd <=10:
  precoPGr = 35
  precoTot = pesoProdGr * precoPGr
if codPaisOrg == 1:
  imp = 0
elif codPaisOrg == 2:
  imp = precoTot * 0.15
elif codPaisOrg == 3:
  imp = precoTot * 0.25
valTot = precoTot + imp
print("\nO peso do produto de código {0} em gramas é {1:,.0f}g." . format(codProd,pesoProdGr))
print("O preço total do produto é R$ {0:,.2f}." .format(precoTot))
print("O imposto incidente sobre a operação com esse produto é R$ {0:,.2f}." .format(imp))
print("O valor total da NF é R$ {0:,.2f}." .format(valTot))
# Out:
# Informe os seguintes dados para o cálculo do valor total do produto:
# Código do produto (de 1 a 10): 6
# Peso do produto (em kg): 54
# Código do país de origem do produto (de 1 a 3): 1
#
# O peso do produto de código 6 em gramas é 54,000g.
# O preço total do produto é R$ 1,350,000.00.
# O imposto incidente sobre a operação com esse produto é R$ 0.00.
# O valor total da NF é R$ 1,350,000.00.

# %% [markdown]
# ### 21. Faça um programa que receba:
#
# * o código do estado de origem da carga de um caminhão, supondo que a digitação do código do estado seja sempre válida, isto é, um número inteiro entre 1 e 5;
# * o peso da carga do caminhão em toneladas;
# * o código da carga, supondo que a digitação do código seja sempre válida, isto é, um número inteiro entre 10 e 40.
#
# | CÓDIGO DO ESTADO| IMPOSTO|
# |---|---|
# |1|35%|
# |2|25%|
# |3|15%|
# |4|5%|
# |5|Isento|
#
# >
#
# CÓDIGO DA CARGA|PREÇO POR QUILO
# ---|---
# 10 a 20|100
# 21 a 30|250
# 31 a 40|400
#
# Calcule e mostre:
# * o peso da carga do caminhão convertido em quilos;
# * o preço da carga do caminhão;
# * o valor do imposto, sabendo que o imposto é cobrado sobre o preço da carga do caminhão e depende do estado de origem;
# * o valor total transportado pelo caminhão, preço da carga mais imposto.
#
# ```
# LEIA codigo_do_estado, peso_em_toneladas, codigo_da_carga
#
# peso_em_quilos = peso_em_toneladas * 1000
#
# ESCREVA peso_em_quilos
#
# SE cod_carga >= 10 E cod_carga <= 20
#     preco_da_carga = 100 * peso_em_quilos
# SE cod_carga >= 21 E cod_carga <= 30
#     preco_da_carga = 250 * peso_em_quilos
# SE cod_carga >= 31 E cod_carga <= 40
#     preco_da_carga = 340 * peso_em_quilos
#
# ESCREVA preco_da_carga
#
# SE codigo_do_estado = 1
#     imposto = 35/100 * preco_da_carga
# SE cod_est = 2
#     imposto = 25/100 * preco_da_carga
# SE cod_est = 3
#     imposto = 15/100 * preco_ds_carga
# SE cod_est = 4
#     imposto = 5/100 * preco_da_carga
# SE cod_est = 5
#     imposto = 0
#
# ESCREVA imposto
#
# valor_total = preco_da_carga + imposto
#
# ESCREVA valor_total
#
# ```

# %%
# 21. Faça um programa que receba
print("Informe os seguintes dados para o cálculo do valor total da carga transportada pelo caminhão:")
codEst = int(input("Código do Estado de origem da carga (de 1 a 5): "))
pesoCargaTn = float(input("Peso do produto (em toneladas): "))
codCarga = int(input("Código da carga (de 10 a 40): "))
pesoCargaKg = pesoCargaTn * 1000
if 10 <= codCarga <= 20:
  precoPKg = 100
elif codCarga <= 30:
  precoPKg = 250
elif codCarga <=40:
  precoPKg = 400
if codEst == 1:
  alImp = 0.35
elif codEst == 2:
  alImp = 0.25
elif codEst == 3:
  alImp = 0.15
elif codEst == 4:
  alImp = 0.05
elif codEst == 5:
  alImp = 0
precoTot = pesoCargaKg * precoPKg
impDevido = precoTot * alImp
valTot = precoTot + impDevido
print("\nO peso da carga de código {0} em quilogramas é {1:,.0f}kg." . format(codCarga,pesoCargaKg))
print("O preço total da carga é R$ {0:,.2f}." .format(precoTot))
print("O imposto incidente sobre a operação com essa carga é R$ {0:,.2f}." .format(impDevido))
print("O valor total da NF da carga transportada pelo caminhão é R$ {0:,.2f}." .format(valTot))
# Out:
# Informe os seguintes dados para o cálculo do valor total da carga transportada pelo caminhão:
# Código do Estado de origem da carga (de 1 a 5): 3
# Peso do produto (em toneladas): 6
# Código da carga (de 10 a 40): 15
#
# O peso da carga de código 15 em quilogramas é 6,000kg.
# O preço total da carga é R$ 600,000.00.
# O imposto incidente sobre a operação com essa carga é R$ 90,000.00.
# O valor total da NF da carga transportada pelo caminhão é R$ 690,000.00.

# %% [markdown]
# ### 22. Faça um programa que receba o salário base e o tempo de serviço de um funcionário. Calcule e mostre:
# * O imposto, conforme a tabela a seguir.
# * A gratificação, de acordo com a tabela a seguir.
# * O salário líquido, ou seja, salário base menos imposto mais gratificação.
# * A categoria, que está na tabela a seguir.
#
# ```
# LEIA salario_base, tempo
#
# SE salario_base < 200
#     imposto = 0
# SENÃO SE salario_base <= 450
#     imposto = 3/100 * salario_base
# SENÃO SE sal_base < 700
#     imposto = 8/100 * salario_base
# SENÃO
#     imposto = 12/100 * salario_base
#
# ESCREVA imposto
#
# SE salario_base > 500
#     SE tempo <= 3
#          gratificacao = 20
#     SENÃO
#         gratificacao = 30
# SENÃO
#     SE tempo <= 3
#         gratificacao = 23
#     SENÃO SE tempo < 6
#         gratificacao = 35
#     SENÃO gratificacao = 33
#
# ESCREVA gratificacao
#
# salario_liquido = salario_base – imposto + gratificacao
#
# ESCREVA salario_liqquido
#
# SE salario_liquido <= 350
#     ESCREVA “Classificação A”
# SENÃO
#     SE salario_liqquido < 600
#         ESCREVA “Classificação B”
#     SENÃO
#         ESCREVA “Classificação C”
# ```

# %%
# 22. Faça um programa que receba o salário base e o tempo de serviço de um funcionário. Calcule e mostre:
salBase = float(input('Informe o salário base: R$ '))
tempServ = int(input('Informe o tempo de serviço (em anos): '))
if salBase < 200:
  imposto = 0
elif salBase <= 450:
  imposto = salBase * (3/100)
elif salBase <700:
  imposto = salBase * (8/100)
else:
  imposto = salBase * (12/100)
if salBase > 500:
  if tempServ <= 3:
    gratif = 20
  else:
    gratif = 30
else:
  if tempServ <= 3:
    gratif = 23
  elif tempServ < 6:
    gratif = 35
  else:
    gratif = 33 
salLiq = salBase - imposto + gratif
if salLiq <= 350:
  classif = 'Classificação A'
elif salLiq < 600:
  classif = 'Classificação B'
else:
  classif = 'Classificação C'
print("\nO imposto incidente sobre o salário base de R$ {0:.2f} é R$ {1:.2f}." .format(salBase,imposto))
print("O valor da gratificação é R$ {0:.2f}." .format(gratif))
print("O salário líquido a receber pelo funcionário é R$ {0:.2f}." .format(salLiq))
print('O funcionário possui a seguinte classificação quanto ao salário líquido recebido: {0}.' .format(classif))
# Out:
# Informe o salário base: R$ 2500
# Informe o tempo de serviço (em anos): 10
#
# O imposto incidente sobre o salário base de R$ 2500.00 é R$ 300.00.
# O valor da gratificação é R$ 30.00.
# O salário líquido a receber pelo funcionário é R$ 2230.00.
# O funcionário possui a seguinte classificação quanto ao salário líquido recebido: Classificação C.

# %% [markdown]
# ### 23. Faça um programa que:
#
# * receba o valor do salário mínimo,
# * o turno de trabalho (M — matutino; V — vespertino; ou N — noturno),
# * a categoria (O — operário; G — gerente)
# * número de horas trabalhadas no mês de um funcionário.
#
# *Suponha a digitação apenas de dados válidos e, quando houver digitação de letras, utilize maiúsculas.*
#
# **Calcule e mostre:**
#
# * O coeficiente do salário, de acordo com a tabela a seguir.
#
# TURNO DE TRABALHO|VALOR DO COEFICIENTE
# ---|---
# M - Matutino|10% do salário mínimo
# V - Vespertino|15% do salário mínimo
# N - Noturno|20% do salário mínimo
#
# * O valor do salário bruto, ou seja, o número de horas trabalhadas multiplicado pelo valor do coeficiente do salário.
#
# * O imposto, de acordo com a tabela a seguir.
#
# CATEGORIA| SALÁRIO BRUTO|IMPOSTO SOBRE O SALÁRIO BRUTO
# ---|---|---
# O - Operário|>= 300,00|5%
# O - Operário|< 300,00|3%
# G - Gerente|>= 300,00|6%
# G - Gerente|< 300,00|4%
#
# * A gratificação, de acordo com as regras a seguir. Se o funcionário preencher todos os requisitos a seguir, sua gratificação será de 50,00; caso contrário, será de 30,00. Os requisitos são:
#  * Turno: Noturno
#   * Número de horas trabalhadas: Superior a 80 horas
#   * O auxílio alimentação, de acordo com as seguintes regras.
# * Auxilio alimentação, um terço do seu salário bruto; caso contrário, será de metade do seu salário bruto. Os requisitos são:
#   * Se o funcionário preencher algum dos requisitos a seguir, seu auxílio alimentação será de
#   * Categoria: Operário
#   * Coeficiente do salário: < = 25
# * O salário líquido, ou seja, salário bruto menos imposto mais gratificação mais auxílio alimentação.
# * A classificação, de acordo com a tabela a seguir:
#
# SALÁRIO LÍQUIDO|MENSAGEM
# ---|---
# Menor que 350,00|Mal remunerado
# Entre 350 e 600,00|Normal
# Maior que 600,00|Bem remunerado
#
# ```
# LEIA salario_minino, turno, categoria, numero_de_horas_trabalhadas
# SE turno = “M”
#      coeficiente = 10/100 * salario_minino
# SE turno = “V”
#      coeficiente = 15/100 * salario_minino
# SE turno = “N”
#      coeficiente = 12/100 * salario_minino
#
# ESCREVA coeficiente
#
# salario_bruto = numero_de_horas_trabalhadas * coeficiente
#
# ESCREVA salario_bruto
#
# SE categoria = “O”
#     SE sal_bruto >= 300
#         imposto = 5/100 * sal_bruto
#     SENÃO
#         imposto = 3/100 * sal_bruto
# SENÃO
#     SE salario_bruto >= 400
#         imposto = 6/100 * salario_bruto
#     SENÃO
#          imposto = 4/100 * salario_bruto
#
# ESCREVA imposto
#
# SE turno = “N” E numero_de_horas_trabalhadas > 80
#     gratificacao = 50
# SENÃO
#     gratificacao = 30
#
# ESCREVA gratificacao
#
# SE categoria = “O” OU coeficiente <= 25
#     auxilio = 1/3 * salario_bruto
# SENÃO
#     auxilio = 1/2 * salario_bruto
#
# ESCREVA auxilio
#
# salario_liquido = salario_bruto – imposto + gratificacao + auxilio
#
# ESCREVA salario_liquido
#
# SE salario_liquido < 350
#      ESCREVA “Mal Remunerado”
# SE salario_liquido >= 350 E salario_liqquido <= 600
#      ESCREVA “Normal”
# SE salario_liquido > 600
#      ESCREVA “Bem Remunerado”
# ```

# %%
# 23. Faça um programa que:
salMin = float(input('Informe o valor do salário mínimo: R$ '))
turnoTrab = input('Informe o turno de trabalho conforme uma das opções a seguir (apenas a letra maiúscula):\n -M: Matutino\n -V: Vespertino\n -N: Noturno\n Turno: ')
categ = input('Informe a categoria de trabalhador conforme uma das opções a seguir (apenas a letra maiúscula):\n -O: Operário\n -G: Gerente\n Categoria: ')
nroHTrab = float(input("Informe o número de horas trabalhadas pelo funcinário: "))
if turnoTrab == 'M' or turnoTrab == 'm':
  turno = 'matutino'
  coefic = salMin * 10/100
elif turnoTrab == 'V' or turnoTrab == 'v':
  turno = 'vespertino'
  coefic = salMin * 15/100
elif turnoTrab == 'N' or turnoTrab == 'n':
  turno = 'noturno'
  coefic = salMin * 12/100
salBruto = nroHTrab * coefic
if categ == 'O' or categ == 'o':
  if salBruto >= 300:
    imposto = salBruto * 5/100
  else:
    imposto = salBruto * 3/100
elif categ == 'G' or categ == 'g':
  if salBruto >= 300:
    imposto = salBruto * 6/100
  else:
    imposto = salBruto * 4/100
if (turnoTrab == 'N' or turnoTrab == 'n') and nroHTrab > 80:
  gratif = 50
else:
  gratif = 30
if (categ == 'O' or categ == 'o') or coefic <= 25:
  aux = salBruto * 1/3
else:
  aux = salBruto * 1/2
salLiq = salBruto - imposto + gratif + aux
if salLiq < 350:
  classifRem = 'Mal remunerado'
elif 350 <= salLiq <= 600:
  classifRem = 'Normal'
else:
  classifRem = 'Bem remunerado'
print('\nO coeficiente do funcionário por realizar o turno {0} é {1:.2f}' .format(turno,coefic))
print('O salário bruto do funcionário é R$ {0:.2f}.' .format(salBruto))
print("O imposto incidente sobre o salário do funcionário é R$ {0:.2f}." .format(imposto))
print("O valor da gratificação é R$ {0:.2f}." .format(gratif))
print("O valor do auxílio é R$ {0:.2f}." .format(aux))
print('O salário líquido do funcionário é R$ {0:.2f}.' .format(salLiq))
print('O funcionário possui a seguinte classificação quanto ao salário líquido recebido: {0}.' .format(classifRem))
# Out:
# Informe o valor do salário mínimo: R$ 1000
# Informe o turno de trabalho conforme uma das opções a seguir (apenas a letra maiúscula):
#  -M: Matutino
#  -V: Vespertino
#  -N: Noturno
#  Turno: N
# Informe a categoria de trabalhador conforme uma das opções a seguir (apenas a letra maiúscula):
#  -O: Operário
#  -G: Gerente
#  Categoria: O
# Informe o número de horas trabalhadas pelo funcinário: 20
#
# O coeficiente do funcionário por realizar o turno noturno é 120.00
# O salário bruto do funcionário é R$ 2400.00.
# O imposto incidente sobre o salário do funcionário é R$ 120.00.
# O valor da gratificação é R$ 30.00.
# O valor do auxílio é R$ 800.00.
# O salário líquido do funcionário é R$ 3110.00.
# O funcionário possui a seguinte classificação quanto ao salário líquido recebido: Bem remunerado.

# %% [markdown]
# ### 24. Faça um programa que receba de um produto:
#
# * o preço
# *   o tipo (A — alimentação; L — limpeza; e V — vestuário)
# * a refrigeração (S — produto que necessita de refrigeração; e N — produto que não necessita de refrigeração) .
#
# **Suponha que haverá apenas a digitação de dados válidos e, quando houver digitação de letras, utilize maiúsculas. Calcule e mostre:**
#
# * O valor adicional, de acordo com a tabela a seguir:
#
# REFRIGERAÇÃO|TIPO|PREÇO|VALOR ADICIONAL
# ---|---|---|---
# N|A|<  15,00|2,00|
#  | |>= 15,00|5,00|
#  |---------|--------------|-------------------------------
#  |L|< 10,00|1,50
#  | |>= 10,00|2,50
#   |---------|--------------|-------------------------------
#  |V|< 30,00|3,00
#  ||>= 30,00|2,50
#   --------------------------|---------|--------------|-------------------------------
# S|A||8,00
# |L||0,00
# |V||0,00
#
# * O valor do imposto, de acordo com a regra a seguir.
#
# PREÇO|PERCENTUAL SOBRE O PREÇO
# ---|---
# < 25,00|5%
# >= 25,00|8%
#
# O preço de custo, ou seja, preço mais imposto.
# O desconto, de acordo com a regra a seguir.
#
# O produto que não preencher nenhum dos requisitos a seguir terá desconto de 3%, caso contrário, 0 (zero). Os requisitos são:
# * Tipo: A
# * Refrigeração: S
#
# * O novo preço, ou seja, preço de custo mais adicional menos desconto.
# * A classificação, de acordo com a regra a seguir.
#
# NOVO PREÇO|CLASSIFICAÇÃO
# ---|---
# <= 50,00|Barato
# Entre 50,00 e 100,00|Normal
# >= 100,00|Caro
#
#
# ```
#
# ALGORITMO
#
# DECLARE pre, valor_adic, imposto NUMÉRICO
# pre_custo, desconto, novo_pre NUMÉRICO
# tipo, refrig LITERAL
# LEIA pre, tipo, refrig
#
# SE refrig = “N”
# ENTÃO INÍCIO
#     SE tipo = “A”
#       ENTÃO INÍCIO
#         SE pre < 15
#           ENTÃO valor_adic
#           SENÃO valor_adic
#       FIM
#
#     SE tipo = “L”
#       ENTÃO INÍCIO
#       SE pre < 10
#         ENTÃO valor_adic
#         SENÃO valor_adic
#       FIM
#
#     SE tipo = “V”
#     ENTÃO INÍCIO
#       SE pre < 30
#         ENTÃO valor_adic
#         SENÃO valor_adic
#    FIM
# FIM
#
# SENÃO INÍCIO
#   SE tipo = “A”
#     ENTÃO valor_adic = 8
#   SE tipo = “L”
#     ENTÃO valor_adic = 0
#   SE tipo = “V”
#     ENTÃO valor_adic = 0
# FIM
#
# ESCREVA valor_adic
#
# SE pre < 25
#   ENTÃO imposto = 5/100 * pré
#   SENÃO imposto = 8/100 * pre
#
# ESCREVA imposto
# pre_custo = pre + imposto
# ESCREVA pre_custo
# SE tipo ≠ “A” E refrig ≠ “S”
#   ENTÃO desconto = 3/100 * pre_custo
#   SENÃO desconto = 0
#
# ESCREVA desconto
# novo_pre = pre_custo + valor_adic – desconto
# ESCREVA novo_pre
# SE novo_pre <= 50
#   ENTÃO ESCREVA “Barato”
#   SENÃO SE novo_pre < 100
#       ENTÃO ESCREVA “Normal”
#       SENÃO ESCREVA “Caro”
#
# FIM_ALGORITMO

# %%
# 24. Faça um programa que receba de um produto:
precoProd = float(input('Informe o preço do produto: R$ '))
tipoProd = input('Informe o tipo de produto conforme uma das opções abaixo (utilize letras maiúsculas):\n -A: Alimentação\n -L: Limpeza\n -V: Vestuário\n Tipo: ')
refrig = input('Informe sobre a necessidade de refrigeração do produto conforme as opções abaixo:\n -S - produto necessita de refrigeração\n -N - produto não necessita de refrigeração\n Refrigeração? ')
if refrig == 'S':
  if tipoProd == 'A':
    vlAdic = 8
  else:
    vlAdic = 0
else:
  if tipoProd == 'A':
    if precoProd < 15:
      vlAdic = 2
    else:
      vlAdic = 5
  elif tipoProd == 'L':
    if precoProd < 10:
      vlAdic = 1.5
    else:
      vlAdic = 2.5
  elif tipoProd == 'V':
    if precoProd < 30:
      vlAdic = 3
    else:
      vlAdic = 2.5
print('\nO valor adicional ao preço da mercadoria devido ao tipo de produto e necessidade de refrigeração é R$ {0:.2f}.' .format(vlAdic))
precoProd = precoProd + vlAdic
if precoProd <= 25:
  imposto = precoProd * 5/100
else:
  imposto = precoProd * 8/100
print("O imposto incidente sobre a mercadoria é R$ {0:.2f}." .format(imposto))
precoCusto = precoProd + imposto
print("O preço de custo da mercadoria é R$ {0:.2f}." .format(precoCusto))
if tipoProd == 'A' and refrig == 'S':
  desc = precoCusto * 3/100
else:
  desc = 0
precoAConF = precoCusto - desc
print("O preço a consumidor final é R$ {0:.2f}." .format(precoAConF))
if precoAConF <= 50:
  classif = 'Barato'
elif precoAConF < 100:
  classif = 'Normal'
else:
  classif = 'Caro'
print('O preço é considerado {0}.' .format(classif))
# Out:
# Informe o preço do produto: R$ 50
# Informe o tipo de produto conforme uma das opções abaixo (utilize letras maiúsculas):
#  -A: Alimentação
#  -L: Limpeza
#  -V: Vestuário
#  Tipo: A
# Informe sobre a necessidade de refrigeração do produto conforme as opções abaixo:
#  -S - produto necessita de refrigeração
#  -N - produto não necessita de refrigeração
#  Refrigeração? S
#
# O valor adicional ao preço da mercadoria devido ao tipo de produto e necessidade de refrigeração é R$ 8.00.
# O imposto incidente sobre a mercadoria é R$ 4.64.
# O preço de custo da mercadoria é R$ 62.64.
# O preço a consumidor final é R$ 60.76.
# O preço é considerado Normal.

# %% [markdown]
# ### 25. Faça um programa que receba a medida de um ângulo em graus. Calcule e mostre o quadrante em que se localiza esse ângulo. Considere os quadrantes da trigonometria e, para ângulos maiores que 360° ou menores que −360o, reduzí-los, mostrando também o número de voltas e o sentido da volta (horário ou anti-horário).
# ALGORITMO
#
# DECLARE angulo, voltas NUMÉRICO
#
# LEIA angulo
#
# SE angulo > 360 OU angulo < -360
#
#   ENTÃO INÍCIO
#
#     voltas = parte inteira(angulo / 360)
#     angulo = RESTO(angulo / 360)
#
#   FIM
#
#   SENÃO voltas = 0
#
# SE angulo = 0 OU angulo = 90 OU angulo = 180
#
#   OU angulo = 270 OU angulo = 360
#
#   OU angulo = -90 OU angulo = -180
#
#   OU angulo = -270 OU angulo = -360
#
#   ENTÃO ESCREVA “Está em cima de algum dos eixos”
#
#   SE (angulo > 0 E angulo < 90) OU (angulo < -270 E angulo > -360)
#
#     ENTÃO ESCREVA “1o Quadrante”
#
#   SE (angulo > 90 E angulo < 180) OU (angulo < -180 E angulo > -270)
#
#     ENTÃO ESCREVA “2o Quadrante”
#
#   SE (angulo > 180 E angulo < 270) OU (angulo < -90 E angulo > -180)
#
#     ENTÃO ESCREVA “3o Quadrante”
#
#   SE (angulo > 270 E angulo < 360) OU (angulo < 0 E angulo > -90)
#
#     ENTÃO ESCREVA “4o Quadrante”
#
#   ESCREVA voltas, “ volta(s) no sentido “
#
# SE angulo < 0
#
#     ENTÃO ESCREVA “horário”
#
#     SENÃO ESCREVA “anti-horário”
#
# FIM_ALGORITMO

# %%
# 25. Faça um programa que receba a medida de um ângulo em graus. Calcule e mostre o quadrante em que se localiza esse ângulo. Considere os quadrantes da trigonometria e, para ângulos maiores que 360° ou menores que −360o, reduzí-los, mostrando também o número de voltas e o sentido da volta (horário ou anti-horário).
angulo = float(input('Informe o ângulo (em graus): '))
if angulo > 360:
  voltas = angulo // 360
  angulo = angulo % 360
elif angulo < -360:
  angulo = angulo * (-1)
  voltas = angulo // 360
  angulo = (angulo % 360) * (-1)
else:
  voltas = 0
if angulo == 0 or angulo == 90 or angulo == 180 or angulo == 270 or angulo == -90 or angulo == -180 or angulo == -270:
  print('O ângulo está sobre algum dos eixos')
elif 0 < angulo < 90 or -360 < angulo < -270:
  print('O ângulo está no 1º quadrante.')
elif 90 < angulo < 180 or -270 < angulo < -180:
  print('O ângulo está no 2º quadrante.')
elif 180 < angulo < 270 or -180 < angulo < -90:
  print('O ângulo está no 3º quadrante.')
elif 270 < angulo < 360 or -90 < angulo < 0:
  print('O ângulo está no 4º quadrante.')
if angulo < 0:
  sentido = 'horário'
else:
  sentido = 'anti-horário'
print('O ângulo informado completa {0} voltas no sentido {1}.' .format(voltas,sentido))
# Out:
# Informe o ângulo (em graus): -1200
# O ângulo está no 3º quadrante.
# O ângulo informado completa 3.0 voltas no sentido horário.
