# %% [markdown]
# # Exercícios para construir programas com ENTRADA, PROCESSAMENTO e SAÍDA

# %% [markdown]
# ### 1. Faça um programa que leia um número, multiplique ele por 2 e apresente o resultado.
#       LEIA numero
#       resultado = numero * 2
#       ESCREVA resultado

# %%
# Faça um programa que leia um número, multiplique ele por 2 e apresente o resultado.
numero = int(input("Digite um número para ser multiplicado por 2: "))
resultado = numero * 2
print("O número apresentado multiplicado por 2 é {0}." .format(resultado))
# Out:
# Digite um número para ser multiplicado por 2: 56
# O número apresentado multiplicado por 2 é 112.

# %% [markdown]
# ### 2. Faça um programa que:
# * receba quatro números inteiros
# * calcule e mostre a soma desses números.
#
#     LEIA n1, n2, n3, n4
#
#     soma = n1 + n2 + n3 + n4
#
#     ESCREVA soma

# %%
# Faça um programa que receba quatro números inteiros e calcule e mostre a soma desses números.
n1 = int(input("Digite o primeiro número: "))
n2 = int(input("Digite o segundo número: "))
n3 = int(input("Digite o terceiro número: "))
n4 = int(input("Digite o quarto número: "))
soma= n1 + n2 + n3 + n4
print("A soma dos quatro números é {0}." .format(soma))
# Out:
# Digite o primeiro número: 96
# Digite o segundo número: 85
# Digite o terceiro número: 74
# Digite o quarto número: 52
# A soma dos quatro números é 307.

# %% [markdown]
# ### 3. Faça um programa que receba três notas, calcule e mostre a média aritmética.
#       LEIA nota1, nota2, nota3
#       media = (nota1 + nota2 + nota3) / 3
#       ESCREVA media

# %%
# Faça um programa que receba três notas, calcule e mostre a média aritmética.
p1= float(input('Digite a nota na P1: ')) 
p2= float(input('Digite a nota na P2: ')) 
p3= float(input('Digite a nota na P3: ')) 
media = (p1+p2+p3)/3 
print('A média aritmética dos três números é {0:.2f}.' .format(media))
# Out:
# Digite a nota na P1: 45
# Digite a nota na P2: 89
# Digite a nota na P3: 100
# A média aritmética dos três números é 78.00.

# %% [markdown]
# ### 4. Faça um programa que:
# * receba o salário de um funcionário
# * calcule e mostre o novo salário, sabendo-se que este sofreu um aumento de 25%.
#
#       LEIA salario
#       novoSalario = salario + (salario * 25 / 100)
#       ESCREVA novoSalario

# %%
# Faça um programa que receba o salário de um funcionário e calcule e mostre o novo salário, sabendo-se que este sofreu um aumento de 25%.
atualSalario=float(input("Qual o salário atual? R$ "))
novoSalario= atualSalario * 1.25
print("O novo salário é R$ {0:.2f}" .format(novoSalario))
# Out:
# Qual o salário atual? R$ 10000.00
# O novo salário é R$ 12500.00

# %% [markdown]
# ### 5. Faça um programa que receba o salário de um funcionário e o percentual de aumento, calcule e mostre o valor do aumento e o novo salário.
#
#       LEIA salario, percentual
#       aumento = salario * percentual/100
#       ESCREVA aumento
#       novo_salario = salario + aumento
#       ESCREVA novo_salario

# %%
# Faça um programa que receba o salário de um funcionário e o percentual de aumento, calcule e mostre o valor do aumento e o novo salário.
atualSalario=float(input("Qual o salário atual? R$ "))
percent=float(input("Qual o percentual de aumento? Em %: "))
aumento = atualSalario * percent/100
print("O valor do aumento é R$ {0:.2f}.".format(aumento))
novoSalario = atualSalario + aumento
print("O novo salário é R$ {0:.2f}.".format(novoSalario))
# Out:
# Qual o salário atual? R$ 10000.00
# Qual o percentual de aumento? Em %: 5.5
# O valor do aumento é R$ 550.00.
# O novo salário é R$ 10550.00.

# %% [markdown]
# ### 6. Faça um programa que receba o salário base de um funcionário, calcule e mostre o salário a receber, sabendo-se que o funcionário tem gratificação de 5% sobre o salário base e paga imposto de 7% também sobre o salário base.
#
#     LEIA salario
#     gratificacao = salario * 5 / 100
#     imposto = salario * 7 / 100
#     salario_a_receber ← salario + gratificacao − imposto
#     ESCREVA salrario_a_receber

# %%
# Faça um programa que receba o salário base de um funcionário, calcule e mostre o salário a receber, sabendo-se que o funcionário tem gratificação de 5% sobre o salário base e paga imposto de 7% também sobre o salário base.
salario = float(input("Qual é o salário base? R$ "))
gratif = salario* 0.05
imposto = salario* 0.07
salarioBruto = salario + gratif
salarioLiquido = salario + gratif - imposto
print("O salário bruto é R$ {0:.2f} e o salário líquido é R$ {1:.2f}." .format(salarioBruto,salarioLiquido))
# Out:
# Qual é o salário base? R$ 10000.00
# O salário bruto é R$ 10500.00 e o salário líquido é R$ 9800.00.

# %% [markdown]
# ### 7. Faça um programa que receba o salário base de um funcionário, calcule e mostre seu salário a receber, sabendo-se que o funcionário tem gratificação de 50,00 sobre o salário base e paga imposto que deve ser lido e é aplicado sobre o salário base.
#
#     LEIA salario, perImposto
#     imposto = salario * perImposto / 100
#     salario_a_receber = salario + 50 - imposto
#     ESCREVA salario_a_receber

# %%
# Faça um programa que receba o salário base de um funcionário, calcule e mostre seu salário a receber, sabendo-se que o funcionário tem gratificação de 50,00 sobre o salário base e paga imposto que deve ser lido e é aplicado sobre o salário base.
salario = float(input("Qual é o salário base? R$ "))
percImposto = float(input("Qual o percectual do imposto? Em %: "))
gratif =  50
imposto = salario * percImposto / 100
salarioBruto = salario + gratif
salarioLiquido = salario + gratif - imposto
print("O salário bruto é R$ {0:.2f} e o salário líquido é R$ {1:.2f}." .format(salarioBruto,salarioLiquido))
# Out:
# Qual é o salário base? R$ 10000.00
# Qual o percectual do imposto? Em %: 7
# O salário bruto é R$ 10050.00 e o salário líquido é R$ 9350.00.

# %% [markdown]
# ### 8. Faça um programa que receba o valor de um depósito e o valor da taxa de juros, calcule e mostre o valor do rendimento e o valor total depois do rendimento de um mês.
#
#       LEIA deposito, taxa
#       rendimento = deposito * taxa / 100
#       total = deposito + rendimento
#       ESCREVA rendimento
#       ESCREVA total

# %%
# Faça um programa que receba o valor de um depósito e o valor da taxa de juros, calcule e mostre o valor do rendimento e o valor total depois do rendimento de um mês.
capital = float(input("Qual o valor do depóstito realizado ou a ser realizado? R$ "))
taxaJuros = float(input("Qual o taxa de juros a ser paga mensalmente pelo depósito? Em %: "))
rendimento = capital * taxaJuros /100
montante = capital + rendimento
print("O rendimento do depósito no primeiro mês é R$ {0:.2f} e o montante final do depósito após um mês é R$ {1:.2f}." .format(rendimento, montante))
# Out:
# Qual o valor do depóstito realizado ou a ser realizado? R$ 500
# Qual o taxa de juros a ser paga mensalmente pelo depósito? Em %: .6
# O rendimento do depósito no primeiro mês é R$ 3.00 e o montante final do depósito após um mês é R$ 503.00.

# %% [markdown]
# ### 9. Faça um programa que calcule e mostre a área de um triângulo. Sabe-se que: Área = (base * altura) / 2.
#
#     LEIA base, altura
#     area = (base * altura) / 2
#     ESCREVA area

# %%
# Faça um programa que calcule e mostre a área de um triângulo. Sabe-se que: Área = (base * altura) / 2.
base= float(input('Qual é a medida da base do triângulo? Em cm: ')) 
altura= float(input('Qual é a altura do triângulo? Em cm: '))
area = (base * altura) / 2
print("A área desse triângulo é {0}cm² ou {1}m²." .format(area,(area ** 0.5)))
# Out:
# Qual é a medida da base do triângulo? Em cm: 200
# Qual é a altura do triângulo? Em cm: 100
# A área desse triângulo é 10000.0cm² ou 100.0m².

# %% [markdown]
# ### 10. Faça um programa que calcule e mostre a área de um círculo. Sabe-se que: Área = p * R 2.
#
#     LEIA raio
#     area = 3.1415 * raio ** 2
#     ESCREVA area

# %%
# Faça um programa que calcule e mostre a área de um círculo. Sabe-se que: Área = p * R 2.
raio= float(input('Qual é a medida do raio do círculo? Em cm: '))
areaCirculo = 3.1415 * raio ** 2
print("A área de um círculo de {0:.1f}cm de raio é {1:.1f}cm² ou {2:.1f}m²." .format(raio,areaCirculo,(areaCirculo ** 0.5)))
# Out:
# Qual é a medida do raio do círculo? Em cm: 6
# A área de um círculo de 6.0cm de raio é 113.1cm² ou 10.6m².

# %% [markdown]
# ### 11. Faça um programa que receba um número positivo e maior que zero, calcule e mostre:
# * O número digitado ao quadrado
# * O número digitado ao cubo
# * A raiz do número digitado
# * A raiz cúbica do número digitao
#
#       LEIA numero
#       quadrado = numero ** 2
#       cubo = numero ** 3
#       raiz_quadrada = numero ** ½
#       raiz_cubica = numero ** ⅓
#       ESCREVA quadrado, cubo, raiz_quadrada, raiz_cubica

# %%
# Faça um programa que receba um número positivo e maior que zero, calcule e mostre
numero = float(input("Digite qualquer número maior que zero: "))
quadrado = numero ** 2
cubo = numero ** 3
raizQuad = numero ** (1/2)
raizCub = numero ** (1/3)
print("O quadrado de {0} é {1:.1f}." .format(numero,quadrado))
print("O cubo de {0} é {1:.1f}." .format(numero,cubo))
print("A raiz quadrada de {0} é {1:.1f}." .format(numero,raizQuad))
print("A raiz cúbica de {0} é {1:.1f}." .format(numero,raizCub))
# Out:
# Digite qualquer número maior que zero: 64
# O quadrado de 64.0 é 4096.0.
# O cubo de 64.0 é 262144.0.
# A raiz quadrada de 64.0 é 8.0.
# A raiz cúbica de 64.0 é 4.0.

# %% [markdown]
# ### 12. Faça um programa que receba dois números maiores que zero, calcule e mostre um elevado ao outro.
#
#       LEIA numero1, numero2
#       numero1_elevado_numero2 = numero1 ** numero2
#       numero2_elevado_numero1 = numero2 ** numero1
#       ESCREVA numero1_elevado_numero2, numero2_elevado_numero1

# %%
# Faça um programa que receba dois números maiores que zero, calcule e mostre um elevado ao outro.
n1= float(input('Digite um número maior que zero: ')) 
n2= float(input('Digite outro número maior que zero:  ')) 
n1ElevadoAn2 = n1 ** n2
n2ElevadoAn1 = n2 ** n1
print("O primeiro número ({0}) elevado ao segundo número ({1}) é {2}." .format(n1,n2,n1ElevadoAn2))
print("O segundo número ({0}) elevado ao primeiro número ({1}) é {2}.".format(n2,n1,n2ElevadoAn1))
# Out:
# Digite um número maior que zero: 3
# Digite outro número maior que zero:  4
# O primeiro número (3.0) elevado ao segundo número (4.0) é 81.0.
# O segundo número (4.0) elevado ao primeiro número (3.0) é 64.0.

# %% [markdown]
# ### 13. Sabe-se que:
#
# * pé = 12 polegadas
# * 1 jarda = 3 pés
# * 1 milha = 1,760 jarda
#
# Faça um programa que receba uma medida em pés, faça as conversões a seguir e mostre os resultados.
#
# * Polegadas;
# * Jardas;
# * Milhas.
#
#       LEIA pes
#       polegadas = pes * 12
#       jardas = pes / 3
#       milhas = jardas / 1760
#       ESCREVA polegadas, jardas, milhas

# %%
# Faça um programa que receba uma medida em pés, faça as conversões a seguir e mostre os resultados.
pes = int(input("Qual é a medida em pés? "))
polegadas = pes * 12
jardas = pes / 3
milhas = jardas /1760
print(" {0} pés medem {1} polegadas, {2:.2f} jardas e {3:.2f} milhas." .format(pes,polegadas,jardas,milhas))
# Out:
# Qual é a medida em pés? 5000
#  5000 pés medem 60000 polegadas, 1666.67 jardas e 0.95 milhas.

# %% [markdown]
# ### 14. Faça um programa que receba o ano de nascimento de uma pessoa e o ano atual, calcule e mostre:
# * a idade dessa pessoa;
# * quantos anos ela terá em 2050.
#       LEIA ano_atual
#       LEIA ano_nascimento
#       idade_atual = ano_atual − ano_nascimento
#       idade_2050 = 2050 − ano_nascimento
#       ESCREVA idade_atual

# %%
# Faça um programa que receba o ano de nascimento de uma pessoa e o ano atual, calcule e mostre a idade dessa pessoa; quantos anos ela terá em 2050.
anoAtual = int(input("Em que ano estamos, segundo o calendário gregoriano? R.: "))
anoNasc= int(input("Qual o seu ano de nascimento? R.: "))
idadeAtual= anoAtual - anoNasc
idade2050 = 2050 - anoNasc
print("A sua idade atual é de",idadeAtual,"anos.")
print("A sua idade em 2050 será de",idade2050,"anos.")
# Out:
# Em que ano estamos, segundo o calendário gregoriano? R.: 2019
# Qual o seu ano de nascimento? R.: 1986
# A sua idade atual é de 33 anos.
# A sua idade em 2050 será de 64 anos.

# %% [markdown]
# #### 15. O custo ao consumidor de um carro novo é a soma do preço de fábrica com o percentual de lucro do distribuidor e dos impostos aplicados ao preço de fábrica. Faça um programa que receba o preço de fábrica de um veículo, o percentual de lucro do distribuidor e o percentual de impostos, calcule e mostre:
# * o valor correspondente ao lucro do distribuidor;
# * o valor correspondente aos impostos;
# * o preço final do veículo.
#         LEIA preco_de_fabrica
#         LEIA percentual_de_lucro_do_distribuidr
#         LEIA percentual_do_imposto
#         lucro_do_distribuidor = preco_de_fabrica *
#               percentual_de_lucro_do_distribuido / 100
#         valor_do_imposto = preco_de_fabrica *
#               percentual_de_imposto / 100
#         preco_final =  preco_de_fabrica + lucro_do_distribuidor +
#               valor_do_imposto
#         ESCREVA lucro_do_distribuidor
#         ESCREVA valor_do_imposto
#         ESCREVA preco_final

# %%
# Faça um programa que receba o preço de fábrica de um veículo, o percentual de lucro do distribuidor e o percentual de impostos, calcule e mostre
precoFabr = float(input("Qual o preço de fábrica do veículo novo? R$ "))
percLucroDistr = float(input("Qual o percentual de lucro do distribuidor de veículos? Em %: "))
percImposto = float(input("Qual o percentual de imposto aplicado sobre o preço de fábrica do veículo? Em %: "))
lucroDistr = precoFabr * percLucroDistr /100
imposto = precoFabr * percImposto / 100
precoFinal = precoFabr + lucroDistr + imposto
print("O lucro por veículo do distribuidor de veículos é R$ {0:.2f}." .format(lucroDistr))
print("O valor do imposto por veículo a ser debitado do distribuidor é R$ {0:.2f}." .format(imposto))
print("O preço final de venda do veículo a consumidor final é R$ {0:.2f}." .format(precoFinal))
# Out:
# Qual o preço de fábrica do veículo novo? R$ 20000.00
# Qual o percentual de lucro do distribuidor de veículos? Em %: 20
# Qual o percentual de imposto aplicado sobre o preço de fábrica do veículo? Em %: 7.5
# O lucro por veículo do distribuidor de veículos é R$ 4000.00.
# O valor do imposto por veículo a ser debitado do distribuidor é R$ 1500.00.
# O preço final de venda do veículo a consumidor final é R$ 25500.00.

# %% [markdown]
# ### 16. Faça um programa que receba o número de horas trabalhadas e o valor do salário mínimo, calcule e mostre o salário a receber, seguindo estas regras:
# * a hora trabalhada vale a metade do salário mínimo.
# * o salário bruto equivale ao número de horas trabalhadas multiplicado pelo valor da hora trabalhada.
# * o imposto equivale a 3% do salário bruto.
# * o salário a receber equivale ao salário bruto menos o imposto.
#       LEIA quantidade_de_horas_trabalhadas
#       LEIA valor_do_salario_minimo
#       valor_hora_trabalhada = valor_do_salario_minimo / 2
#       valor_salario_bruto = valor_da_hora_trabalhada *
#             quantidade_de_horas_trabalhadas
#       impostos = valor_salario_bruto * 3 / 100
#       Valor_salario_liquido =  ← valor_salario_bruto - impostos
#           ESCREVA valor_salario_liquido

# %%
# Faça um programa que receba o número de horas trabalhadas e o valor do salário mínimo, calcule e mostre o salário a receber
quantHtrab = float(input("Qual a quantidade de horas trabalhadas? "))
salMin = float(input("Qual o valor do salário mínimo? R$ "))
valHtrab = salMin / 2
salBruto = valHtrab * quantHtrab
imposto = salBruto * 3/100
salLiq = salBruto - imposto
print("O salário líquido a receber é R$ {0:.2f}." .format(salLiq))
# Out:
# Qual a quantidade de horas trabalhadas? 8
# Qual o valor do salário mínimo? R$ 998
# O salário líquido a receber é R$ 3872.24.

# %% [markdown]
# ### 17. Um trabalhador recebeu seu salário e o depositou em sua conta bancária. Esse trabalhador emitiu dois cheques e agora deseja saber seu saldo atual. Sabe-se que cada operação bancária de retirada paga um imposto chamado CPMF de 0,38% e o saldo inicial da conta está zerado.
#
#       LEIA salario
#       LEIA valor_cheque1
#       LEIA valor_cheque2
#       cpmf_cheque1 = valor_cheque1 * 0.038 / 100
#       saque1 = valor_cheque1 + cpmf_cheque1
#       cpmf_cheque2 = cheque2 * 0.038 / 100
#       saque2 = valor_cheque2 + cpmf_cheque2
#       saldo = salario - saque1 - saque2
#       ESCREVA saldo

# %%
# Um trabalhador recebeu seu salário e o depositou em sua conta bancária. Esse trabalhador emitiu dois cheques e agora deseja saber seu saldo atual.
salario = float(input("Qual o valor do salário recebido? R$ "))
vCheque1 = float(input("Qual o valor do primeiro cheque depositado? R$ "))
vCheque2 = float(input("Qual o valor do segundo cheque depositado? R$ "))
cpmfCheque1 = vCheque1 * 0.38 / 100
custoSaque1 = vCheque1 + cpmfCheque1
cpmfCheque2 = vCheque2 * 0.38 / 100
custoSaque2 = vCheque2 + cpmfCheque2
saldoFin = salario - custoSaque1 - custoSaque2
print("O valor do saldo final da conta do trabalhador após o a compensação dos dois cheques é R$",saldoFin)
# Out:
# Qual a valor do salário recebido? R$ 10000
# Qual o valor do primeiro cheque depositado? R$ 2500
# Qual o valor do segundo cheque depositado? R$ 3700
# O valor do saldo final da conta do trabalhador após o a compensação dos dois cheques é R$ 3776.44

# %% [markdown]
# ### 18. Pedro comprou um saco de ração com peso em quilos. Ele possui dois gatos, para os quais fornece a quantidade de ração em gramas. A quantidade diária de ração fornecida para cada gato é sempre a mesma. Faça um programa que receba o peso do saco de ração e a quantidade de ração fornecida para cada gato, calcule e mostre quanto restará de ração no saco após cinco dias.
#
#       LEIA peso_saco
#       LEIA racao_gato1
#       LEIA racao_gato2
#       Racao_gato1 = racao_gato1 / 1000
#       racao_gato2 = racao_gato2 / 1000
#       total_final = peso_saco − 5 * (racao_gato1 + racao_gato2)
#       ESCREVA total_final

# %%
# Faça um programa que receba o peso do saco de ração e a quantidade de ração fornecida para cada gato, calcule e mostre quanto restará de ração no saco após cinco dias.
pesoSaco = float(input("Qual o peso do saco de ração de gatos em quilos? Kg: "))
racGato1gr = float(input("Quantos gramas de ração o primeiro gato consome por dia? G: "))
racGato2gr = float(input("Quantos gramas de ração o segundo gato consome por dia? G: "))
racGato1Kg = racGato1gr / 1000
racGato2Kg = racGato2gr / 1000
pesoSacoFinal = pesoSaco - 5* (racGato1Kg + racGato2Kg)
print("O peso do saco de ração após 5 dias será de {0:.3f}kg ou {1:.01f}g." .format(pesoSacoFinal,(pesoSacoFinal*1000)))
# Out:
# Qual o peso do saco de ração de gatos em quilos? Kg: 4
# Quantos gramas de ração o primeiro gato consome por dia? G: 50
# Quantos gramas de ração o segundo gato consome por dia? G: 75
# O peso do saco de ração após 5 dias será de 3.375kg ou 3375.0g.

# %% [markdown]
# ### 19. Cada degrau de uma escada tem X de altura. Faça um programa que receba essa altura e a altura que o usuário deseja alcançar subindo a escada, calcule e mostre quantos degraus ele deverá subir para atingir seu objetivo, sem se preocupar com a altura do usuário. Todas as medidas fornecidas devem estar em metros.
#       LEIA altura_do_degrau
#       LEIA altura_desejada
#       quantidade_de_degraus = altura_desejada // altura_do_degrau
#       ESCREVA quantidade_degraus
# **Observação**: o operador **//** em Python é utilizado para pegar a parte inteira de uma divisão

# %%
# Faça um programa que receba essa altura e a altura que o usuário deseja alcançar subindo a escada, calcule e mostre quantos degraus ele deverá subir para atingir seu objetivo, sem se preocupar com a altura do usuário. Todas as medidas fornecidas devem estar em metros.
altDegrau = float(input("Qual a altura do degrau, em metros? M: "))
altDesejada = float(input("Qual é a diferença de altura entre do piso atual e o piso que se deseja alcançar, em metros? M: "))
quantDegraus = altDesejada // altDegrau
print("A quantidade de degraus de {0:.1f}cm que o usuário deverá percorrer entre um piso e outro é de {1:.0f} degraus.".format((altDegrau*1000),quantDegraus))
# Out:
# Qual a altura do degrau, em metros? M: .015
# Qual é a diferença de altura entre do piso atual e o piso que se deseja alcançar, em metros? M: 3
# A quantidade de degraus de 15.0cm que o usuário deverá percorrer entre um piso e outro é de 200 degraus.

# %% [markdown]
# ### 20. Faça um programa que receba a medida do ângulo (em graus) formado por uma escada apoiada no chão e encostada na parede e a altura da parede onde está a ponta da escada. Calcule e mostre a medida dessa escada. Observação: as funções trigonométricas implementadas nas linguagens de programação trabalham com medidas de ângulos em radianos.
#       LEIA angulo
#       LEIA altura
#       radiano = angulo * 3.14 / 180
#       escada = altura / seno(radiano)
#       ESCREVA escada
# **Observação**: Para usar senho em Python, deve-se usar esta linha de código **import math** e esta, no cálculo, **math.sin(número)**.

# %%
# Faça um programa que receba a medida do ângulo (em graus) formado por uma escada apoiada no chão e encostada na parede e a altura da parede onde está a ponta da escada.
import math
anguloInEscChao = float(input("Qual o angulo formado pela escada e o chão onde ela está apoiada, em graus? Ângulo: "))
altChaoParPontaEscada = float(input("Qual é a altura da parede que é tocada pela ponta superior da escada, em metros? M: "))
radiano = anguloInEscChao * 3.14 / 180
altEscada = altChaoParPontaEscada / math.sin(radiano)
print("A altura da escada deve ser {0:.2f}m." .format(altEscada))
# Out:
# Qual o angulo formado pela escada e o chão onde ela está apoiada, em graus? Ângulo: 30
# Qual é a altura da parede que é tocada pela ponta superior da escada, em metros? M: 5
# A altura da escada deve ser 10.00m.

# %% [markdown]
# ### 21. Uma pessoa deseja pregar um quadro em uma parede. Faça um programa para calcular e mostrar a que distância a escada deve estar da parede. A pessoa deve fornecer o tamanho da escada e a altura em que deseja pregar o quadro. Lembre-se de que o tamanho da escada deve ser maior que a altura que se deseja alcançar.
#       LEIA Z
#       LEIA X
#       Y = Z ** 2 - X ** 2
#       Y = Y **1/2
#       ESCREVA Y

# %%
# Faça um programa para calcular e mostrar a que distância a escada deve estar da parede.
altEscada = float(input("Qual é a altura da escada, em metros? M: "))
altQuadro = float(input("Qual é a altura em que o quadro deverá ser pendurado, em metros? M: "))
altPontaEscada = altQuadro + 0.5
distEscParede = altEscada ** 2 - altPontaEscada ** 2
distEscParede = distEscParede ** 0.5
print("A distância que a escada deverá estar da parede para que o quadro seja pendurado com tranquilidade é de {0:.2f}m." .format(distEscParede))
# Out:
# Qual é a altura da escada, em metros? M: 5
# Qual é a altura em que o quadro deverá ser pendurado, em metros? M: 2.5
# A distância que a escada deverá estar da parede para que o quadro seja pendurado com tranquilidade é de 4.00m.

# %% [markdown]
# ###22. Sabe-se que o quilowatt de energia custa um quinto do salário mínimo. Faça um programa que receba o valor do salário mínimo e a quantidade de quilowatts consumida por uma residência. Calcule e mostre:
#
#
# * o valor de cada quilowatt;
# * o valor a ser pago por essa residência;
# * o valor a ser pago com desconto de 15%.
#       LEIA valor_do_salario
#       LEIA quantidade_de_quilowatt
#       valor_do_quilowatt = valor_do_salario / 5
#       valor_em_reais ← valor_do_quilowatt * qquantidade_de_quilowatt
#       valor_do_desconto = valor_em_reais * 15 / 100
#       valor_com_desconto =  valor_em_reais − valor_do_desconto
#       ESCREVA valor_do_quilowatt
#       ESCREVA valor_em_reais
#       ESCREVA valor_com_desconto

# %%
# Faça um programa que receba o valor do salário mínimo e a quantidade de quilowatts consumida por uma residência.
salarioMin = float(input("Qual o valor do salário mínimo? R$ "))
quantKw = float(input("Qual a quantidade de quilowatts consumida pela residência no período? KW: "))
valKw = salarioMin / 5
custoTotal = quantKw * valKw
descConta = custoTotal * 15 / 100
totalPagoDesc = custoTotal - descConta
print("O preço do quilowatts é R$ {0:.2f}." .format(valKw))
print("O custo total de energia para essa residência no período é R$ {0:.2f}." .format(custoTotal))
print("O preço a ser pago com desconto de 15% nessa conta de energia é R$ {0:.2f}." .format(totalPagoDesc))
# Out:
# Qual o valor do salário mínimo? R$ 998
# Qual a quantidade de quilowatts consumida pela residência no período? KW: 6
# O preço do quilowatts é R$ 199.60.
# O custo total de energia para essa residência no período é R$ 1197.60.
# O preço a ser pago com desconto de 15% nessa conta de energia é R$ 1017.96.

# %% [markdown]
# ### 23. Faça um programa que receba um número real, encontre e mostre:
#
# * a parte inteira desse número;
# * a parte fracionária desse número;
# * o arredondamento desse número.
#
#       LEIA numero
#       parte_inteira = numero // 1
#       parte_fracionaria = numero - parte_inteira
#       numero_arredondado = arredonda (numero)
#       ESCREVA parte_inteira
#       ESCREVA parte_fracionaria
#       ESCREVA numero_arredondado
#
# **Observação**: Para arredondar um número em Python, usa-se a função **round(numero)**, onde se o número real/float estiver em igual distância entre o inteiro de cima e o inteiro de baixo, esta função arredonda para o número par mais próximo.

# %%
# Faça um programa que receba um número real, encontre e mostre a parte inteira desse número; a parte fracionária desse número; o arredondamento desse número.
numero = float(input("Digite um número real qualquer: "))
partInteira = numero // 1
partFrac = numero - partInteira
numArred = round(numero)
print("A parte inteira desse número real é {0:.0f}." .format(partInteira))
print("A parte fracionária desse número real até a quarta casa decimal é {0:.4f}." .format(partFrac))
print("Esse número real arredondado é {0}." .format(numArred))
# Out:
# Digite um número real qualquer: 456.123
# A parte inteira desse número real é 456.
# A parte fracionária desse número real até a quarta casa decimal é 0.1230.
# Esse número real arredondado é 456.

# %% [markdown]
# ### 24. Faça um programa que receba uma hora formada por hora e minutos (um número real), calcule e mostre a hora digitada apenas em minutos. Lembre-se de que:
# * para quatro e meia, deve-se digitar 4.30;
# * os minutos vão de 0 a 59.
#       LEIA hora
#       h = pegar a parte inteira da variável hora
#       minutos = hora − h
#       conversao = (h * 60) + (minutos * 100)
#       ESCREVA conversao

# %%
#  Faça um programa que receba uma hora formada por hora e minutos (um número real), calcule e mostre a hora digitada apenas em minutos.
horamin = float(input("Qual é quantidade de horas que deseja converter em minutos? Utilize ponto no lugar de dois pontos: "))
h = horamin // 1
minutos = horamin - h
conversao = (h*60) + (minutos * 100)
print("As {0:.2f}h correspondem a {1:.0f}min." .format(horamin,conversao))
# Out:
# Qual é quantidade de horas que deseja converter em minutos? Utilize ponto no lugar de dois pontos: 5.40
# As 5.40h correspondem a 340min.

# %% [markdown]
# ### 25. Faça um programa que receba o custo de um espetáculo teatral e o preço do convite desse espetáculo. Esse programa deverá calcular e mostrar a quantidade de convites que devem ser vendidos para que, pelo menos, o custo do espetáculo seja alcançado.
#
#       LEIA custo
#       LEIA convite
#       quantidade = custo / convite
#       ESCREVA quantidade

# %%
# Quantidade de Convites para custear o Espetáculo
custo= float(input("Qual o custo de todo o Espetáculo? R$ "))
convite= float(input("Qual o custo do convite para o Espetáculo? R$ "))
quantidade = custo / convite
print("Será necessário vender pelo menos {0:.0f} convites para custear todo o Espetáculo." .format(quantidade))
# Out:
# Qual o custo de todo o Espetáculo? R$ 10500.00
# Qual o custo do convite para o Espetáculo? R$ 35
# Será necessário vender pelo menos 300 convites para custear todo o Espetáculo.
